# %% [markdown]
# # Pandas - data types and basic operations
# In the last lesson, we introduced the pandas library and its base classes: `Series`,` DataFrame` and `Index`. However, we took them as static objects, which we only viewed.
# In this lesson, we will begin to edit existing tables. We will show:
# * how to **add** or **remove columns** and **rows**
# * how to **change the value of a specific cell**
# * what **data types** are suitable for which purpose
# * **arithmetic** and **logical operations** that can be performed on columns
# * **filtering** and **sorting rows**
#
# And since you definitely don't want to lose the results of the work
# * **saving the results** to external files will be useful in the end.

# %%
# Mandatory import
import pandas as pd

# %%
#Optional import to disable warningns

#import warnings
#warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## Manipulating DataFrames
# To warm up, we will work with a small table containing some basic information about the planets, which you can easily find, for example, on Wikipedia (https://en.wikipedia.org/wiki/Planet).

# %%
planets = pd.DataFrame({
    
"name": ["Mercury", "Venus", "Earth", "Mars", "Jupiter", "Saturn", "Uranus", "Neptune"],
"symbol": ["☿", "♀", "⊕", "♂", "♃", "♄", "♅", "♆"],
"equatorian_diameter": [0.39, 0.72, 1.00, 1.52, 5.20, 9.54, 19.22, 30.06],
"orbital_period": [0.24, 0.62, 1, 1.88, 11.86, 29.46, 84.01, 164.8]})

planets = planets.set_index("name") # It will be easier for you to work with the name as index
planets
# Out:
#         symbol  equatorian_diameter  orbital_period
# name
# Mercury      ☿                 0.39            0.24
# Venus        ♀                 0.72            0.62
# Earth        ⊕                 1.00            1.00
# Mars         ♂                 1.52            1.88
# Jupiter      ♃                 5.20           11.86
# Saturn       ♄                 9.54           29.46
# Uranus       ♅                19.22           84.01
# Neptune      ♆                30.06          164.80

# %% [markdown]
# ### Add a new column
# When we want to add a new column (`Series`), we assign it to a `DataFrame` as a dictionary value - that is, in square brackets with the column name.
#
# `pandas` handles both the `Series` and the regular `list`, so we can create a new list and add it as a new column with number of moons for each planet.

# %%
moons = [0, 0, 1, 2, 79, 82, 27, 14] 
# Alternatively moons = pd.Series ([...])

planets["moons"] = moons #define a new column
planets
# Out:
#         symbol  equatorian_diameter  orbital_period  moons
# name
# Mercury      ☿                 0.39            0.24      0
# Venus        ♀                 0.72            0.62      0
# Earth        ⊕                 1.00            1.00      1
# Mars         ♂                 1.52            1.88      2
# Jupiter      ♃                 5.20           11.86     79
# Saturn       ♄                 9.54           29.46     82
# Uranus       ♅                19.22           84.01     27
# Neptune      ♆                30.06          164.80     14

# %% [markdown]
# 💡 In this case, we have directly modified the existing `DataFrame`.
#
# Most methods / operations in `pandas` (eg. `set_index`) by default always return a new object with the modification applied, leaving the original object in an unchanged state.
#
# It is generally a good habit & we will stick to it. However, column assignment is one of the accepted exceptions to this otherwise recognized rule.
#
# `DataFrame` also offers an `assign` method (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.assign.html), which does not modify the table but creates a copy of it. with columns added (or replaced). If you want to avoid the annoying tracking of which table you changed or not, we can only recommend `assign` to you.
#
# By the way, you can make a copy of the table at any time using the `copy` method (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html) - this is useful when writing functions , where the input table is modified for various reasons.

# %%
# New temporary DataFrame

planets.assign(has_rings = [False, False, False, False, True, True, True, True])
# Out:
#         symbol  equatorian_diameter  orbital_period  moons  has_rings
# name
# Mercury      ☿                 0.39            0.24      0      False
# Venus        ♀                 0.72            0.62      0      False
# Earth        ⊕                 1.00            1.00      1      False
# Mars         ♂                 1.52            1.88      2      False
# Jupiter      ♃                 5.20           11.86     79       True
# Saturn       ♄                 9.54           29.46     82       True
# Uranus       ♅                19.22           84.01     27       True
# Neptune      ♆                30.06          164.80     14       True

# %%
planets # The planets df has remained unchanged.
# Out:
#         symbol  equatorian_diameter  orbital_period  moons
# name
# Mercury      ☿                 0.39            0.24      0
# Venus        ♀                 0.72            0.62      0
# Earth        ⊕                 1.00            1.00      1
# Mars         ♂                 1.52            1.88      2
# Jupiter      ♃                 5.20           11.86     79
# Saturn       ♄                 9.54           29.46     82
# Uranus       ♅                19.22           84.01     27
# Neptune      ♆                30.06          164.80     14

# %%
planets2 = planets.copy()
planets2["has_rings"] = [False, False, False, False, True, True, True, True]
planets2
# The original planets df will not change
# Out:
#         symbol  equatorian_diameter  orbital_period  moons  has_rings
# name
# Mercury      ☿                 0.39            0.24      0      False
# Venus        ♀                 0.72            0.62      0      False
# Earth        ⊕                 1.00            1.00      1      False
# Mars         ♂                 1.52            1.88      2      False
# Jupiter      ♃                 5.20           11.86     79       True
# Saturn       ♄                 9.54           29.46     82       True
# Uranus       ♅                19.22           84.01     27       True
# Neptune      ♆                30.06          164.80     14       True

# %% [markdown]
# > ### Task
# Add a column with the (approximate) year of discovery (`" discovered "`). Try both methods
# You can find the data at https://en.wikipedia.org/wiki/Timeline_of_discovery_of_Solar_System_planets_and_their_moons.

# %%
#Your code goes here...

# %% [markdown]
# ### Scalar value

# %% [markdown]
# Sometimes, one scalar value can be used for all the values of a new column (we use it very rarely) - the same value is then used in all rows:

# %%
planets["is_planet"] = True
planets
# Out:
#         symbol  equatorian_diameter  orbital_period  moons  is_planet
# name
# Mercury      ☿                 0.39            0.24      0       True
# Venus        ♀                 0.72            0.62      0       True
# Earth        ⊕                 1.00            1.00      1       True
# Mars         ♂                 1.52            1.88      2       True
# Jupiter      ♃                 5.20           11.86     79       True
# Saturn       ♄                 9.54           29.46     82       True
# Uranus       ♅                19.22           84.01     27       True
# Neptune      ♆                30.06          164.80     14       True

# %% [markdown]
# ### Add a new row
# Sometime before 2006 a new planet was added to a list, namely Pluto.
#
# We will insert it into our table as a new row using the `loc` indexer, which we have previously used to access values from the table:

# %%
planets.loc["Pluto"] = ["♇", 39.48, 247.94, 5,"1980", True] # List of values in a row in planets
planets
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27784/2355506630.py in <module>
# ----> 1 planets.loc["Pluto"] = ["♇", 39.48, 247.94, 5,"1980", True] # List of values in a row in planets
#       2 planets
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     721
#     722         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 723         iloc._setitem_with_indexer(indexer, value, self.name)
#     724
#     725     def _validate_key(self, key, axis: int):
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1722
#    1723             if missing:
# -> 1724                 self._setitem_with_indexer_missing(indexer, value)
#    1725                 return
#    1726
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2025                     # must have conforming columns
#    2026                     if len(value) != len(self.obj.columns):
# -> 2027                         raise ValueError("cannot set a row with mismatched columns")
#    2028
#    2029                 value = Series(value, index=self.obj.columns, name=indexer)
#
# ValueError: cannot set a row with mismatched columns

# %% [markdown]
# > ### Task
# Add the Sun or some completely fictional planet to the table

# %%
# Your code goes here

# %% [markdown]
# ### Change cell value(s)
# The "indexers" `.loc` and `.iloc` with two arguments in square brackets refer directly to a specific cell, and by assigning them (again, similarly to a dictionary), the value is written to the appropriate place. You just need to keep the order (row, column).
# Let's come back to the present moment and deprive Pluto of its status:

# %%
planets.loc["Pluto", "is_planet"] = False
planets
# Out:
#         symbol  equatorian_diameter  orbital_period  moons is_planet
# name
# Mercury      ☿                 0.39            0.24    0.0      True
# Venus        ♀                 0.72            0.62    0.0      True
# Earth        ⊕                 1.00            1.00    1.0      True
# Mars         ♂                 1.52            1.88    2.0      True
# Jupiter      ♃                 5.20           11.86   79.0      True
# Saturn       ♄                 9.54           29.46   82.0      True
# Uranus       ♅                19.22           84.01   27.0      True
# Neptune      ♆                30.06          164.80   14.0      True
# Pluto      NaN                  NaN             NaN    NaN     False

# %% [markdown]
# > ⚠ Attention: As with the dictionary it is possible to write a value in a row or column that does not exist!

# %%
planets_bad = planets.copy () # We will make a copy to not mess up with the original df
planets_bad.loc["Earth", "is_star"] = False
planets_bad
# Out:
#         symbol  equatorian_diameter  orbital_period  moons is_planet is_star
# name
# Mercury      ☿                 0.39            0.24    0.0      True     NaN
# Venus        ♀                 0.72            0.62    0.0      True     NaN
# Earth        ⊕                 1.00            1.00    1.0      True   False
# Mars         ♂                 1.52            1.88    2.0      True     NaN
# Jupiter      ♃                 5.20           11.86   79.0      True     NaN
# Saturn       ♄                 9.54           29.46   82.0      True     NaN
# Uranus       ♅                19.22           84.01   27.0      True     NaN
# Neptune      ♆                30.06          164.80   14.0      True     NaN
# Pluto      NaN                  NaN             NaN    NaN     False     NaN

# %% [markdown]
# 💡 You must be wondering what `NaN` means in the table. `NaN` (Not a Number) indicates a **missing**, **invalid**, or **unknown value**.
#
# In our example, we did not enter it, so it is not surprising. We will talk about the issue of missing values and how to deal with them next time, so let us not get nervous about them for now.

# %% [markdown]
# It is also possible to assign to ranges in indexes - we just need to make sure that we assign either a *scalar value* (ie one value for the whole area, a dimensionless non-array) or a multidimensional object (Series, DataFrame, list, ...) of the same shape (number of rows and columns) as the area to which we assign:

# %%
planets.loc["Mercury": "Mars", "has_rings"] = False
planets.loc["Jupiter": "Neptune", "has_rings"] = [True, True, True, True]
planets
# Out:
#         symbol  equatorian_diameter  orbital_period  moons is_planet has_rings
# name
# Mercury      ☿                 0.39            0.24    0.0      True     False
# Venus        ♀                 0.72            0.62    0.0      True     False
# Earth        ⊕                 1.00            1.00    1.0      True     False
# Mars         ♂                 1.52            1.88    2.0      True     False
# Jupiter      ♃                 5.20           11.86   79.0      True      True
# Saturn       ♄                 9.54           29.46   82.0      True      True
# Uranus       ♅                19.22           84.01   27.0      True      True
# Neptune      ♆                30.06          164.80   14.0      True      True
# Pluto      NaN                  NaN             NaN    NaN     False       NaN

# %% [markdown]
# > ### Task
# Create a `has_moon` column that indicates whether a planet has a moon

# %%
#Your code goes here...

# %% [markdown]
# ### Delete a row
# Use the `drop` method (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html) to remove a column or row from the DataFrame.
#
# Its first argument expects the `index` of one or more rows or columns that you want to remove. The `axis` argument indicates in which dimension the operation is to be applied. You can use either the number 0 or 1 (which corresponds to the order from zero in which the keys are referenced when referencing cells), or the name of the dimension:
#
# Part (axis):
# * 0 or "index" → rows
# * 1 or "columns" → columns
# * Numerous other methods and functions use this argument, so make sure you understand it
#
# Now, let's have no mercy on Pluto and delete it from the `DataFrame`- for the `drop` method, the default value of the `axis` argument is 0, so we don't have to write it:

# %%
planets
# Out:
#         symbol  equatorian_diameter  orbital_period  moons is_planet has_rings
# name
# Mercury      ☿                 0.39            0.24    0.0      True     False
# Venus        ♀                 0.72            0.62    0.0      True     False
# Earth        ⊕                 1.00            1.00    1.0      True     False
# Mars         ♂                 1.52            1.88    2.0      True     False
# Jupiter      ♃                 5.20           11.86   79.0      True      True
# Saturn       ♄                 9.54           29.46   82.0      True      True
# Uranus       ♅                19.22           84.01   27.0      True      True
# Neptune      ♆                30.06          164.80   14.0      True      True
# Pluto      NaN                  NaN             NaN    NaN     False       NaN

# %%
planets2 = planets.drop("Neptune", axis =0) # Add axis = "rows" to be explicit
planets2
# Out:
#         symbol  equatorian_diameter  orbital_period  moons is_planet has_rings
# name
# Mercury      ☿                 0.39            0.24    0.0      True     False
# Venus        ♀                 0.72            0.62    0.0      True     False
# Earth        ⊕                 1.00            1.00    1.0      True     False
# Mars         ♂                 1.52            1.88    2.0      True     False
# Jupiter      ♃                 5.20           11.86   79.0      True      True
# Saturn       ♄                 9.54           29.46   82.0      True      True
# Uranus       ♅                19.22           84.01   27.0      True      True
# Pluto      NaN                  NaN             NaN    NaN     False       NaN

# %% [markdown]
# > ### Task
# Create a table from `planets` that will contain neither Uranus nor Neptune (with one command).

# %%
#Your code goes here

# %% [markdown]
# ### Delete a column
# The `drop` method works very similarly for a column, only this time we have to specify the `axis` argument.
#
# Let's remove the unnecessary column with the information that a planet is a planet.

# %%
planets = planets.drop("is_planet", axis="columns")
planets
# Out:
#         symbol  equatorian_diameter  orbital_period  moons has_rings
# name
# Mercury      ☿                 0.39            0.24    0.0     False
# Venus        ♀                 0.72            0.62    0.0     False
# Earth        ⊕                 1.00            1.00    1.0     False
# Mars         ♂                 1.52            1.88    2.0     False
# Jupiter      ♃                 5.20           11.86   79.0      True
# Saturn       ♄                 9.54           29.46   82.0      True
# Uranus       ♅                19.22           84.01   27.0      True
# Neptune      ♆                30.06          164.80   14.0      True
# Pluto      NaN                  NaN             NaN    NaN       NaN

# %%
planets.drop("has_moon", axis="columns", inplace = True)
planets
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_27784/1360992760.py in <module>
# ----> 1 planets.drop("has_moon", axis="columns", inplace = True)
#       2 planets
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['has_moon'] not found in axis"

# %% [markdown]
# The `drop` method, in accordance with the above-mentioned convention, returns a new `DataFrame` (and therefore we must assign the result of the operation to the `planet`). If you want to operate directly on the table, you can use the `del` command (it works the same as the dictionary) or use a special argument `inplace = True`

# %%
# Only at your own risk
# Alternative 1) # del planets["is_planet"]
# Alternative 2) # planets.drop("is_planet", axis=1, inplace=True)

# %% [markdown]
# ## Data types

# %% [markdown]
# #### Data preparation
# We will now leave the planets and look at some interesting characteristics of countries around the world (since the definition of what a country is is somewhat vague, we take into account UN members). We captured data for one particular year of the past decade (because not all data are always available , we take the last year where enough indicators are known).
#
# The data comes mostly from the Gapminder project (https://www.gapminder.org/), we have added just a few more information from wikipedia.
#
# The following code (you don't have to understand it) will download the required file and save it in the local directory.
#
# Alternatively, you can download it manually from https://raw.githubusercontent.com/janpipek/data-pro-pyladies/master/data/countries.csv

# %%
import os
import requests


source = "https://raw.githubusercontent.com/janpipek/data-pro-pyladies/master/data/countries.csv"
countries = source.rsplit("/")[-1]

if not os.path.exists(countries):
    print(f"Filename {countries} is not downloaded yet, Let's go...")
    response = requests.get(source)
    with open(countries, "wb") as out:
        out.write(response.content)
    print(f"File {countries} downloaded successfully.")
else:
    print(f"The file {countries} has already been downloaded, we will use the local copy.")
# Out:
# The file countries.csv has already been downloaded, we will use the local copy.

# %% [markdown]
# And we will open it using the already known function `read_csv` (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) (Note: `pandas` can also open the file directly from the internet, but we prefer to use a local copy so that you can return to work offline).

# %%
# Instead of 'set_index`, we select the index right away when loading

countries = pd.read_csv("countries.csv", index_col="name")

countries = countries.sort_index()
countries
# Out:
#              iso             world_6region world_4region        income_groups  \
# name
# Afghanistan  AFG                south_asia          asia           low_income
# Albania      ALB       europe_central_asia        europe  upper_middle_income
# Algeria      DZA  middle_east_north_africa        africa  upper_middle_income
# Andorra      AND       europe_central_asia        europe          high_income
# Angola       AGO        sub_saharan_africa        africa  upper_middle_income
# ...          ...                       ...           ...                  ...
# Venezuela    VEN                   america      americas  upper_middle_income
# Vietnam      VNM         east_asia_pacific          asia  lower_middle_income
# Yemen        YEM  middle_east_north_africa          asia  lower_middle_income
# Zambia       ZMB        sub_saharan_africa        africa  lower_middle_income
# Zimbabwe     ZWE        sub_saharan_africa        africa           low_income
#
#              is_eu  is_oecd eu_accession  year       area  population  \
# name
# Afghanistan  False    False          NaN  2018   652860.0  34500000.0
# Albania      False    False          NaN  2018    28750.0   3238000.0
# Algeria      False    False          NaN  2018  2381740.0  36980000.0
# Andorra      False    False          NaN  2017      470.0     88910.0
# Angola       False    False          NaN  2018  1246700.0  20710000.0
# ...            ...      ...          ...   ...        ...         ...
# Venezuela    False    False          NaN  2018   912050.0  30340000.0
# Vietnam      False    False          NaN  2018   330967.0  90660000.0
# Yemen        False    False          NaN  2018   527970.0  26360000.0
# Zambia       False    False          NaN  2018   752610.0  14310000.0
# Zimbabwe     False    False          NaN  2018   390760.0  13330000.0
#
#              alcohol_adults  bmi_men  bmi_women  car_deaths_per_100000_people  \
# name
# Afghanistan            0.03    20.62      21.07                           NaN
# Albania                7.29    26.45      25.66                         5.978
# Algeria                0.69    24.60      26.37                           NaN
# Andorra               10.17    27.63      26.43                           NaN
# Angola                 5.57    22.25      23.48                           NaN
# ...                     ...      ...        ...                           ...
# Venezuela              7.60    27.45      28.13                         7.332
# Vietnam                3.91    20.92      21.07                           NaN
# Yemen                  0.20    24.44      26.11                           NaN
# Zambia                 3.56    20.68      23.05                        11.260
# Zimbabwe               4.96    22.03      24.65                        20.850
#
#              calories_per_day  infant_mortality  life_expectancy  \
# name
# Afghanistan            2090.0              66.3            58.69
# Albania                3193.0              12.5            78.01
# Algeria                3296.0              21.9            77.86
# Andorra                   NaN               2.1            82.55
# Angola                 2473.0              96.0            65.19
# ...                       ...               ...              ...
# Venezuela              2631.0              12.9            75.91
# Vietnam                2745.0              17.3            74.88
# Yemen                  2223.0              33.8            67.14
# Zambia                 1930.0              43.3            59.45
# Zimbabwe               2110.0              46.6            60.18
#
#              life_expectancy_female  life_expectancy_male un_accession
# name
# Afghanistan                  65.812                63.101   1946-11-19
# Albania                      80.737                76.693   1955-12-14
# Algeria                      77.784                75.279   1962-10-08
# Andorra                         NaN                   NaN   1993-07-28
# Angola                       64.939                59.213   1976-12-01
# ...                             ...                   ...          ...
# Venezuela                    79.079                70.950   1945-11-15
# Vietnam                      81.203                72.003   1977-09-20
# Yemen                        66.871                63.875   1947-09-30
# Zambia                       65.362                59.845   1964-12-01
# Zimbabwe                     63.944                60.120   1980-08-25
#
# [193 rows x 20 columns]

# %% [markdown]
# Let's select a country and see what kind of data we have in the table.

# %%
countries.loc["Costa Rica"]
# Out:
# iso                                             CRI
# world_6region                               america
# world_4region                              americas
# income_groups                   upper_middle_income
# is_eu                                         False
# is_oecd                                       False
# eu_accession                                    NaN
# year                                           2018
# area                                        51100.0
# population                                4860000.0
# alcohol_adults                                 5.81
# bmi_men                                       26.48
# bmi_women                                     27.03
# car_deaths_per_100000_people                  6.319
# calories_per_day                             2848.0
# infant_mortality                                8.5
# life_expectancy                               81.42
# life_expectancy_female                       82.598
# life_expectancy_male                         77.912
# un_accession                             1945-11-02
# Name: Costa Rica, dtype: object

# %% [markdown]
# At first glance, each field is a different type. But what type exactly?
#
# The `dtypes` attribute (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html) will provide us with an answer.
# For `Series` you will use `dtype ` (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dtype.html), or rather `dtype.name` if you want an equally nice string representation).

# %%
countries.dtypes
# Out:
# iso                              object
# world_6region                    object
# world_4region                    object
# income_groups                    object
# is_eu                              bool
# is_oecd                            bool
# eu_accession                     object
# year                              int64
# area                            float64
# population                      float64
# alcohol_adults                  float64
# bmi_men                         float64
# bmi_women                       float64
# car_deaths_per_100000_people    float64
# calories_per_day                float64
# infant_mortality                float64
# life_expectancy                 float64
# life_expectancy_female          float64
# life_expectancy_male            float64
# un_accession                     object
# dtype: object

# %% [markdown]
#  > 💡 The types in pandas are based on how they are defined by the `numpy` library
#
# `numpy` is useful for working with numeric arrays. It provides vector operations at one or two orders of magnitude faster than their pure Python equivalents. (side-note: Vectorization is a practice of replacing explicit loops with array expressions)
#
# A `data type` object (an instance of numpy.dtype class) describes how the bytes in the fixed-size block of memory corresponding to an array item should be interpreted. Among other things, it describes the following aspects of the data:
#
# * Type of the data (integer, float, Python object, etc.)
# * Size of the data (how many bytes is in e.g. the integer)
#
#
# Fortunately, the somewhat mysterious type system in `numpy` (described in (https://docs.scipy.org/doc/numpy/user/basics.types.html) is slightly simplified in `pandas` and offers just a few useful basic data types that we will use in our course.

# %% [markdown]
# ### Integers
# In Python, there is exactly one type reserved for integers: `int`
# which allows you to work with integers of any size (0, -58 or 123456789012345678901234567890).
#
# In `pandas` you can find `int8`, `int16`,` int32`, `int64`,` uint8`, `uint16`,` uint32` and `uint64` - they all have the same basic features and each has only a certain range of numbers that can be stored in it.
#
# They differ in the amount of memory that one number takes up (the number in the name indicates the number of bits), and whether negative numbers are also supported (the prefix `u` means unsigned - it contains only zero and positive numbers).
#
# Ranges:
# * `int8`: -128 to 127
# * `uint8`: 0 to 255
# * `int16`: -32 768 to 32 767
# * `uint16`: 0 to 65 535
# * `int32`: -2 147 483 648 to 2 147 483 647 (+/- ~ 2 billion)
# * `uint32`: 0 to 4 294 967 295 (up to ~ 4 billion)
# * `int64`: -9 223 372 036 854 775 808 to 9 223 372 036 854 775 807 (+/- ~ 9 trillion)
# * `uint64`: 0 to 18 446 744 073 709 551 615 (up to ~ 18 trillion)
#
# For a detailed explanation of how integers are represented in computer memory, check https://en.wikipedia.org/wiki/Integer.

# %% [markdown]
# In `pandas`, the default integer type is `int64`, and unless you say otherwise, it will automatically be used for integers (in most cases this will be a good choice):

# %%
countries["year"]
# Out:
# name
# Afghanistan    2018
# Albania        2018
# Algeria        2018
# Andorra        2017
# Angola         2018
#                ...
# Venezuela      2018
# Vietnam        2018
# Yemen          2018
# Zambia         2018
# Zimbabwe       2018
# Name: year, Length: 193, dtype: int64

# %%
pd.Series([0, 123, 12345])

# pd.Series ([0, 123, 12345], dtype = "int64") # same
# Out:
# 0        0
# 1      123
# 2    12345
# dtype: int64

# %% [markdown]
# You can use the `dtype` argument to specify exactly which type of integers you want:

# %%
pd.Series([0, 123, 12345], dtype="int16")
# Out:
# 0        0
# 1      123
# 2    12345
# dtype: int16

# %% [markdown]
# > ⚠ Caution: When selecting a specific integer type, you must be careful of ranges, because `pandas` will not warn you if any of your values do not "fit" into the range and discard the part of the binary representation that is left-over. As a result, you get a much smaller number than you expected:

# %%
pd.Series([0, 123, 12345], dtype="int8")
# Out:
# /home/bioinfo/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Values are too large to be losslessly cast to int8. In a future version this will raise OverflowError. To retain the old behavior, use pd.Series(values).astype(int8)
#   """Entry point for launching an IPython kernel.
# 0      0
# 1    123
# 2     57
# dtype: int8

# %% [markdown]
# Now, let's create a `Series`with an exceptionally big number (> 10 trillions) and see what happens:

# %%
pd.Series([0, 123, 123456789012345678901234567890]) #it is no longer an integer
# Out:
# 0                                 0
# 1                               123
# 2    123456789012345678901234567890
# dtype: object

# %% [markdown]
# - If we explicitly request int64, an exception is thrown.- When we let `pandas` do the job, the general type `object` is used and we lose some of the advantages: the column takes up many times more memory and arithmetic operations with it are an order of magnitude or two slower. If this is not our priority, we can leave it just like that.
#
# To sum up, we generally recommend sticking to `int64` or let `pandas` use it for us automatically. Only if strict memory requirements require it, it pays off to look for ways to optimise the performance.

# %% [markdown]
# > ### Task:
# Create a `Series` with data type `uint8`, containing (at least) one small negative number. What will happen?

# %%
#Your code goes here...

# %% [markdown]
# ### Floating numbers
# As with integer values, one type in Python (`float`) corresponds to several types in `pandas`: `float16`,` float32`, `float64`.
#
# The name again includes the number of bits that one number has. Fortunately, in this case, `float64` exactly matches the `float` behavior of Python, the other two types are less accurate and have a smaller scope - apart from optimizing memory requirements for a specific type of data, you probably won't use them.

# %%
countries["bmi_men"]
# Out:
# name
# Afghanistan    20.62
# Albania        26.45
# Algeria        24.60
# Andorra        27.63
# Angola         22.25
#                ...
# Venezuela      27.45
# Vietnam        20.92
# Yemen          24.44
# Zambia         20.68
# Zimbabwe       22.03
# Name: bmi_men, Length: 193, dtype: float64

# %%
# Quite accurate pi
pd.Series([3.14159265])
# Out:
# 0    3.141593
# dtype: float64

# %%
# Not so accurate pi
pd.Series([3.14159265], dtype="float16")
# Out:
# 0    3.140625
# dtype: float16

# %% [markdown]
# > ### Task
# Create a Series of type `float64` only from integers. What will happen?

# %%
#Your code goes here...

# %% [markdown]
# ### Booleans
# This is probably the least surprising data type. It basically behaves the same as the `bool` type in Python. It takes the values `True` and` False` (which can also be considered as 1 and 0 in some operations).
#
# It has another great feature - `Series` and `DataFrame` objects can be filtered using a column of logical type:

# %%
countries["is_oecd"].iloc[:20]
# Out:
# name
# Afghanistan            False
# Albania                False
# Algeria                False
# Andorra                False
# Angola                 False
# Antigua and Barbuda    False
# Argentina              False
# Armenia                False
# Australia               True
# Austria                 True
# Azerbaijan             False
# Bahamas                False
# Bahrain                False
# Bangladesh             False
# Barbados               False
# Belarus                False
# Belgium                 True
# Belize                 False
# Benin                  False
# Bhutan                 False
# Name: is_oecd, dtype: bool

# %%
# Create a new column

pd.Series([True, False, False])
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# Another way of creating it:

# %%
pd.Series([1, 0, 0], dtype="bool")
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# > ### Task
# What happens when you create a `Series` of type `bool` from the strings `"True"` and `"False"` (don&#39;t forget the quotes)?

# %%
#Your code goes here...

# %% [markdown]
# ### Strings, objects
# In the current version of the library `pandas` it is recommended to use a special dtype `string` instead of a general dtype `object`. The difference is more or less aesthetic at the moment (and for convenience we usually won't convert the columns to `string` since it is not likely to improve the performance).

# %%
countries["iso"]
# Out:
# name
# Afghanistan    AFG
# Albania        ALB
# Algeria        DZA
# Andorra        AND
# Angola         AGO
#               ...
# Venezuela      VEN
# Vietnam        VNM
# Yemen          YEM
# Zambia         ZMB
# Zimbabwe       ZWE
# Name: iso, Length: 193, dtype: object

# %% [markdown]
# By default, `strings`, along with other unspecified or unrecognized values, fall into the `object` category.
#
# If you want to be explicit or get some extra type checking, you can specify the data type `string` in the constructor, or convert the column using the `astype` method:

# %%
# countries["iso"].astype("string")

# Pets

pets = pd.Series( ["dog", "cat", "hamster", "tarantula", "boa"], dtype="string")

pets
# Out:
# 0          dog
# 1          cat
# 2      hamster
# 3    tarantula
# 4          boa
# dtype: string

# %%
#pets[0] = 42 #will throw an error

# %% [markdown]
# The `object` data type is the only option if we have heterogeneous data in `Series`:

# %%
pd.Series([1, "two", 3.0]) #String, integer & float
# Out:
# 0      1
# 1    two
# 2    3.0
# dtype: object

# %% [markdown]
# Note that also `lists` can be a value in a column of type `object`:

# %%
# Orders
pd.Series(
[["steak", "potatoes", "cola"], ["tuna", "french fries"], ["soda"]],
    index=["Eva", "Dagma", "Petra"])
# Out:
# Eva      [steak, potatoes, cola]
# Dagma       [tuna, french fries]
# Petra                     [soda]
# dtype: object

# %% [markdown]
# > ### Task:
# 1. What kind of object (and what `dtype`) do we get when we try to get one row from the `planets` table?
# 2. What happens when you convert the column `planet["orbital_period"]` to `object` or `string`?

# %%
#Your code goes here

# %% [markdown]
# ### Date / Time (datetime)
# One of the future lessons deals with time data, but we already have one in the table of countries, so at least for completeness let's explore what `pandas` offers in this regard:
# - Time or date data (*datetime*) as points on the timeline.
# - Time data with time zone designation (*datetimes with time zone*).
# - Time slots (*timedeltas*) as a determination of the length of a section (calculated in nanoseconds)
# - Periods (*periods*) indicate some specified time periods (eg "February 2020")

# %% [markdown]
# 💡 The `to_datetime` function is used to convert from various formats to date / time, which we will use for the following example:

# %%
pd.to_datetime(countries["un_accession"])
# Out:
# name
# Afghanistan   1946-11-19
# Albania       1955-12-14
# Algeria       1962-10-08
# Andorra       1993-07-28
# Angola        1976-12-01
#                  ...
# Venezuela     1945-11-15
# Vietnam       1977-09-20
# Yemen         1947-09-30
# Zambia        1964-12-01
# Zimbabwe      1980-08-25
# Name: un_accession, Length: 193, dtype: datetime64[ns]

# %% [markdown]
# ### Categorical
# If we want to be efficient when working with columns, where values are often repeated (especially strings), we can encode them into categories. This often saves space and speeds up some operations. In such a conversion, `pandas` will find all the unique values in the column, store them in a special list, and store only the indexes in that list. Everything behaves transparently, so when used, you usually don&#39;t even know if you have a column of type `object` or` category`.

# %% [markdown]
# 💡 The `astype` method (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.astype.html) is used for conversion between different data types, which accepts the name as its argumen, dtype to which we want to convert:

# %%
countries.dtypes
# Out:
# iso                              object
# world_6region                    object
# world_4region                    object
# income_groups                    object
# is_eu                              bool
# is_oecd                            bool
# eu_accession                     object
# year                              int64
# area                            float64
# population                      float64
# alcohol_adults                  float64
# bmi_men                         float64
# bmi_women                       float64
# car_deaths_per_100000_people    float64
# calories_per_day                float64
# infant_mortality                float64
# life_expectancy                 float64
# life_expectancy_female          float64
# life_expectancy_male            float64
# un_accession                     object
# dtype: object

# %%
countries["income_groups"].astype("category") #creates only temporary df
countries = countries.astype({"income_groups": "category"}) # changes dtype in a df

# %% [markdown]
# > ### Task
# Can you think of which columns from the `countries` table we should convert to some other type?

# %%
#Your code goes here...

# %% [markdown]
# ## Mathematics
# The `Series` in `pandas` is designed to be as functional as possible. Individual columns can thus become part of arithmetic expressions along with scalar values, other columns, `numpy` arrays of the appropriate shape, and even lists.

# %%
countries
# Out:
#              iso             world_6region world_4region        income_groups  \
# name
# Afghanistan  AFG                south_asia          asia           low_income
# Albania      ALB       europe_central_asia        europe  upper_middle_income
# Algeria      DZA  middle_east_north_africa        africa  upper_middle_income
# Andorra      AND       europe_central_asia        europe          high_income
# Angola       AGO        sub_saharan_africa        africa  upper_middle_income
# ...          ...                       ...           ...                  ...
# Venezuela    VEN                   america      americas  upper_middle_income
# Vietnam      VNM         east_asia_pacific          asia  lower_middle_income
# Yemen        YEM  middle_east_north_africa          asia  lower_middle_income
# Zambia       ZMB        sub_saharan_africa        africa  lower_middle_income
# Zimbabwe     ZWE        sub_saharan_africa        africa           low_income
#
#              is_eu  is_oecd eu_accession  year       area  population  \
# name
# Afghanistan  False    False          NaN  2018   652860.0  34500000.0
# Albania      False    False          NaN  2018    28750.0   3238000.0
# Algeria      False    False          NaN  2018  2381740.0  36980000.0
# Andorra      False    False          NaN  2017      470.0     88910.0
# Angola       False    False          NaN  2018  1246700.0  20710000.0
# ...            ...      ...          ...   ...        ...         ...
# Venezuela    False    False          NaN  2018   912050.0  30340000.0
# Vietnam      False    False          NaN  2018   330967.0  90660000.0
# Yemen        False    False          NaN  2018   527970.0  26360000.0
# Zambia       False    False          NaN  2018   752610.0  14310000.0
# Zimbabwe     False    False          NaN  2018   390760.0  13330000.0
#
#              alcohol_adults  bmi_men  bmi_women  car_deaths_per_100000_people  \
# name
# Afghanistan            0.03    20.62      21.07                           NaN
# Albania                7.29    26.45      25.66                         5.978
# Algeria                0.69    24.60      26.37                           NaN
# Andorra               10.17    27.63      26.43                           NaN
# Angola                 5.57    22.25      23.48                           NaN
# ...                     ...      ...        ...                           ...
# Venezuela              7.60    27.45      28.13                         7.332
# Vietnam                3.91    20.92      21.07                           NaN
# Yemen                  0.20    24.44      26.11                           NaN
# Zambia                 3.56    20.68      23.05                        11.260
# Zimbabwe               4.96    22.03      24.65                        20.850
#
#              calories_per_day  infant_mortality  life_expectancy  \
# name
# Afghanistan            2090.0              66.3            58.69
# Albania                3193.0              12.5            78.01
# Algeria                3296.0              21.9            77.86
# Andorra                   NaN               2.1            82.55
# Angola                 2473.0              96.0            65.19
# ...                       ...               ...              ...
# Venezuela              2631.0              12.9            75.91
# Vietnam                2745.0              17.3            74.88
# Yemen                  2223.0              33.8            67.14
# Zambia                 1930.0              43.3            59.45
# Zimbabwe               2110.0              46.6            60.18
#
#              life_expectancy_female  life_expectancy_male un_accession
# name
# Afghanistan                  65.812                63.101   1946-11-19
# Albania                      80.737                76.693   1955-12-14
# Algeria                      77.784                75.279   1962-10-08
# Andorra                         NaN                   NaN   1993-07-28
# Angola                       64.939                59.213   1976-12-01
# ...                             ...                   ...          ...
# Venezuela                    79.079                70.950   1945-11-15
# Vietnam                      81.203                72.003   1977-09-20
# Yemen                        66.871                63.875   1947-09-30
# Zambia                       65.362                59.845   1964-12-01
# Zimbabwe                     63.944                60.120   1980-08-25
#
# [193 rows x 20 columns]

# %%
# Life expectancy in days
countries["life_exp_days"] = countries["life_expectancy"] * 365
countries
# Out:
#              iso             world_6region world_4region        income_groups  \
# name
# Afghanistan  AFG                south_asia          asia           low_income
# Albania      ALB       europe_central_asia        europe  upper_middle_income
# Algeria      DZA  middle_east_north_africa        africa  upper_middle_income
# Andorra      AND       europe_central_asia        europe          high_income
# Angola       AGO        sub_saharan_africa        africa  upper_middle_income
# ...          ...                       ...           ...                  ...
# Venezuela    VEN                   america      americas  upper_middle_income
# Vietnam      VNM         east_asia_pacific          asia  lower_middle_income
# Yemen        YEM  middle_east_north_africa          asia  lower_middle_income
# Zambia       ZMB        sub_saharan_africa        africa  lower_middle_income
# Zimbabwe     ZWE        sub_saharan_africa        africa           low_income
#
#              is_eu  is_oecd eu_accession  year       area  population  ...  \
# name                                                                   ...
# Afghanistan  False    False          NaN  2018   652860.0  34500000.0  ...
# Albania      False    False          NaN  2018    28750.0   3238000.0  ...
# Algeria      False    False          NaN  2018  2381740.0  36980000.0  ...
# Andorra      False    False          NaN  2017      470.0     88910.0  ...
# Angola       False    False          NaN  2018  1246700.0  20710000.0  ...
# ...            ...      ...          ...   ...        ...         ...  ...
# Venezuela    False    False          NaN  2018   912050.0  30340000.0  ...
# Vietnam      False    False          NaN  2018   330967.0  90660000.0  ...
# Yemen        False    False          NaN  2018   527970.0  26360000.0  ...
# Zambia       False    False          NaN  2018   752610.0  14310000.0  ...
# Zimbabwe     False    False          NaN  2018   390760.0  13330000.0  ...
#
#              bmi_men  bmi_women  car_deaths_per_100000_people  \
# name
# Afghanistan    20.62      21.07                           NaN
# Albania        26.45      25.66                         5.978
# Algeria        24.60      26.37                           NaN
# Andorra        27.63      26.43                           NaN
# Angola         22.25      23.48                           NaN
# ...              ...        ...                           ...
# Venezuela      27.45      28.13                         7.332
# Vietnam        20.92      21.07                           NaN
# Yemen          24.44      26.11                           NaN
# Zambia         20.68      23.05                        11.260
# Zimbabwe       22.03      24.65                        20.850
#
#              calories_per_day  infant_mortality  life_expectancy  \
# name
# Afghanistan            2090.0              66.3            58.69
# Albania                3193.0              12.5            78.01
# Algeria                3296.0              21.9            77.86
# Andorra                   NaN               2.1            82.55
# Angola                 2473.0              96.0            65.19
# ...                       ...               ...              ...
# Venezuela              2631.0              12.9            75.91
# Vietnam                2745.0              17.3            74.88
# Yemen                  2223.0              33.8            67.14
# Zambia                 1930.0              43.3            59.45
# Zimbabwe               2110.0              46.6            60.18
#
#              life_expectancy_female  life_expectancy_male  un_accession  \
# name
# Afghanistan                  65.812                63.101    1946-11-19
# Albania                      80.737                76.693    1955-12-14
# Algeria                      77.784                75.279    1962-10-08
# Andorra                         NaN                   NaN    1993-07-28
# Angola                       64.939                59.213    1976-12-01
# ...                             ...                   ...           ...
# Venezuela                    79.079                70.950    1945-11-15
# Vietnam                      81.203                72.003    1977-09-20
# Yemen                        66.871                63.875    1947-09-30
# Zambia                       65.362                59.845    1964-12-01
# Zimbabwe                     63.944                60.120    1980-08-25
#
#             life_exp_days
# name
# Afghanistan      21421.85
# Albania          28473.65
# Algeria          28418.90
# Andorra          30130.75
# Angola           23794.35
# ...                   ...
# Venezuela        27707.15
# Vietnam          27331.20
# Yemen            24506.10
# Zambia           21699.25
# Zimbabwe         21965.70
#
# [193 rows x 21 columns]

# %%
# Population density
countries["population_density"] = countries["population"] / countries["area"]

# %%
countries
# Out:
#              iso             world_6region world_4region        income_groups  \
# name
# Afghanistan  AFG                south_asia          asia           low_income
# Albania      ALB       europe_central_asia        europe  upper_middle_income
# Algeria      DZA  middle_east_north_africa        africa  upper_middle_income
# Andorra      AND       europe_central_asia        europe          high_income
# Angola       AGO        sub_saharan_africa        africa  upper_middle_income
# ...          ...                       ...           ...                  ...
# Venezuela    VEN                   america      americas  upper_middle_income
# Vietnam      VNM         east_asia_pacific          asia  lower_middle_income
# Yemen        YEM  middle_east_north_africa          asia  lower_middle_income
# Zambia       ZMB        sub_saharan_africa        africa  lower_middle_income
# Zimbabwe     ZWE        sub_saharan_africa        africa           low_income
#
#              is_eu  is_oecd eu_accession  year       area  population  ...  \
# name                                                                   ...
# Afghanistan  False    False          NaN  2018   652860.0  34500000.0  ...
# Albania      False    False          NaN  2018    28750.0   3238000.0  ...
# Algeria      False    False          NaN  2018  2381740.0  36980000.0  ...
# Andorra      False    False          NaN  2017      470.0     88910.0  ...
# Angola       False    False          NaN  2018  1246700.0  20710000.0  ...
# ...            ...      ...          ...   ...        ...         ...  ...
# Venezuela    False    False          NaN  2018   912050.0  30340000.0  ...
# Vietnam      False    False          NaN  2018   330967.0  90660000.0  ...
# Yemen        False    False          NaN  2018   527970.0  26360000.0  ...
# Zambia       False    False          NaN  2018   752610.0  14310000.0  ...
# Zimbabwe     False    False          NaN  2018   390760.0  13330000.0  ...
#
#              bmi_women  car_deaths_per_100000_people  calories_per_day  \
# name
# Afghanistan      21.07                           NaN            2090.0
# Albania          25.66                         5.978            3193.0
# Algeria          26.37                           NaN            3296.0
# Andorra          26.43                           NaN               NaN
# Angola           23.48                           NaN            2473.0
# ...                ...                           ...               ...
# Venezuela        28.13                         7.332            2631.0
# Vietnam          21.07                           NaN            2745.0
# Yemen            26.11                           NaN            2223.0
# Zambia           23.05                        11.260            1930.0
# Zimbabwe         24.65                        20.850            2110.0
#
#              infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Afghanistan              66.3            58.69                  65.812
# Albania                  12.5            78.01                  80.737
# Algeria                  21.9            77.86                  77.784
# Andorra                   2.1            82.55                     NaN
# Angola                   96.0            65.19                  64.939
# ...                       ...              ...                     ...
# Venezuela                12.9            75.91                  79.079
# Vietnam                  17.3            74.88                  81.203
# Yemen                    33.8            67.14                  66.871
# Zambia                   43.3            59.45                  65.362
# Zimbabwe                 46.6            60.18                  63.944
#
#              life_expectancy_male  un_accession  life_exp_days  \
# name
# Afghanistan                63.101    1946-11-19       21421.85
# Albania                    76.693    1955-12-14       28473.65
# Algeria                    75.279    1962-10-08       28418.90
# Andorra                       NaN    1993-07-28       30130.75
# Angola                     59.213    1976-12-01       23794.35
# ...                           ...           ...            ...
# Venezuela                  70.950    1945-11-15       27707.15
# Vietnam                    72.003    1977-09-20       27331.20
# Yemen                      63.875    1947-09-30       24506.10
# Zambia                     59.845    1964-12-01       21699.25
# Zimbabwe                   60.120    1980-08-25       21965.70
#
#             population_density
# name
# Afghanistan          52.844408
# Albania             112.626087
# Algeria              15.526464
# Andorra             189.170213
# Angola               16.611855
# ...                        ...
# Venezuela            33.265720
# Vietnam             273.924591
# Yemen                49.927079
# Zambia               19.013832
# Zimbabwe             34.113011
#
# [193 rows x 22 columns]

# %%
countries.head()
# Out:
#              iso             world_6region world_4region        income_groups  \
# name
# Afghanistan  AFG                south_asia          asia           low_income
# Albania      ALB       europe_central_asia        europe  upper_middle_income
# Algeria      DZA  middle_east_north_africa        africa  upper_middle_income
# Andorra      AND       europe_central_asia        europe          high_income
# Angola       AGO        sub_saharan_africa        africa  upper_middle_income
#
#              is_eu  is_oecd eu_accession  year       area  population  ...  \
# name                                                                   ...
# Afghanistan  False    False          NaN  2018   652860.0  34500000.0  ...
# Albania      False    False          NaN  2018    28750.0   3238000.0  ...
# Algeria      False    False          NaN  2018  2381740.0  36980000.0  ...
# Andorra      False    False          NaN  2017      470.0     88910.0  ...
# Angola       False    False          NaN  2018  1246700.0  20710000.0  ...
#
#              bmi_women  car_deaths_per_100000_people  calories_per_day  \
# name
# Afghanistan      21.07                           NaN            2090.0
# Albania          25.66                         5.978            3193.0
# Algeria          26.37                           NaN            3296.0
# Andorra          26.43                           NaN               NaN
# Angola           23.48                           NaN            2473.0
#
#              infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Afghanistan              66.3            58.69                  65.812
# Albania                  12.5            78.01                  80.737
# Algeria                  21.9            77.86                  77.784
# Andorra                   2.1            82.55                     NaN
# Angola                   96.0            65.19                  64.939
#
#              life_expectancy_male  un_accession  life_exp_days  \
# name
# Afghanistan                63.101    1946-11-19       21421.85
# Albania                    76.693    1955-12-14       28473.65
# Algeria                    75.279    1962-10-08       28418.90
# Andorra                       NaN    1993-07-28       30130.75
# Angola                     59.213    1976-12-01       23794.35
#
#             population_density
# name
# Afghanistan          52.844408
# Albania             112.626087
# Algeria              15.526464
# Andorra             189.170213
# Angola               16.611855
#
# [5 rows x 22 columns]

# %%
# How food prices went up
pd.Series([1.2, 1.5], index = ["bread", "butter"]) + [0.5, 1.2] # list addition
# Out:
# bread     1.7
# butter    2.7
# dtype: float64

# %% [markdown]
# > ### Task
# 1. Calculate the total number of deaths in car accidents in each country (use the columns "population" and "car_deaths_per_100000_people" and simple arithmetic).
# 2. Which country has the highest total number of deaths in car accidents?

# %%
#Your code goes here...

# %% [markdown]
# How long has the country be a member of the UN?

# %%
datetime.now()
# Out:
# datetime.datetime(2022, 4, 28, 18, 27, 49, 719434)

# %%
from datetime import datetime
datetime.now() - pd.to_datetime(countries["un_accession"])
# Out:
# name
# Afghanistan   27554 days 18:28:13.438467
# Albania       24242 days 18:28:13.438467
# Algeria       21752 days 18:28:13.438467
# Andorra       10501 days 18:28:13.438467
# Angola        16584 days 18:28:13.438467
#                          ...
# Venezuela     27923 days 18:28:13.438467
# Vietnam       16291 days 18:28:13.438467
# Yemen         27239 days 18:28:13.438467
# Zambia        20967 days 18:28:13.438467
# Zimbabwe      15221 days 18:28:13.438467
# Name: un_accession, Length: 193, dtype: timedelta64[ns]

# %% [markdown]
# 💡 Floating point numbers can also contain special values:
# * `NaN` (Not a Number)
# * `inf`/`-inf` (plus or minus infinity)
#
# They arise, for example, in case of inappropriate division by zero:

# %%
pd.Series([0, -1, 1]) / pd.Series([0, 0, 0])
# Out:
# 0    NaN
# 1   -inf
# 2    inf
# dtype: float64

# %% [markdown]
# **Warning:** We urge you to be careful when working with limited integer types. Due to their inappropriate conversion, the result can be a so-called overflow and show questionable results. One more reason to stick to `int64`.

# %%
pd.Series([7, 14, 149], dtype="int8") * 2
# Out:
# /home/bioinfo/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Values are too large to be losslessly cast to int8. In a future version this will raise OverflowError. To retain the old behavior, use pd.Series(values).astype(int8)
#   """Entry point for launching an IPython kernel.
# 0    14
# 1    28
# 2    42
# dtype: int8

# %% [markdown]
# ## Comparisons

# %% [markdown]
# Not only numerical but also logical operators can be used for `Series`. The result is not one logical value, but a column of logical values.

# %%
# 15 liters of pure alcohol per person per year will be considered the limit of excessive drinking
# (not consulted with doctors!)
# In which countries do people drink a lot? (on average)

countries["alcohol_adults"] > 15
# Out:
# name
# Afghanistan    False
# Albania        False
# Algeria        False
# Andorra        False
# Angola         False
#                ...
# Venezuela      False
# Vietnam        False
# Yemen          False
# Zambia         False
# Zimbabwe       False
# Name: alcohol_adults, Length: 193, dtype: bool

# %%
countries["alcohol_adults"].head()
# Out:
# name
# Afghanistan     0.03
# Albania         7.29
# Algeria         0.69
# Andorra        10.17
# Angola          5.57
# Name: alcohol_adults, dtype: float64

# %%
# Let's examine a specific country
countries.loc["Costa Rica", "alcohol_adults"] > 15
# Out:
# False

# %%
countries.loc["Czechia", "alcohol_adults"] > 15
# Out:
# True

# %%
# Are men fatter than women in each country?
countries["bmi_men"] > countries["bmi_women"]
# Out:
# name
# Afghanistan    False
# Albania         True
# Algeria        False
# Andorra         True
# Angola         False
#                ...
# Venezuela      False
# Vietnam        False
# Yemen          False
# Zambia         False
# Zimbabwe       False
# Length: 193, dtype: bool

# %% [markdown]
# > ### Task
# Find out if men or women live longer in a particular country

# %%
countries.columns
# Out:
# Index(['iso', 'world_6region', 'world_4region', 'income_groups', 'is_eu',
#        'is_oecd', 'eu_accession', 'year', 'area', 'population',
#        'alcohol_adults', 'bmi_men', 'bmi_women',
#        'car_deaths_per_100000_people', 'calories_per_day', 'infant_mortality',
#        'life_expectancy', 'life_expectancy_female', 'life_expectancy_male',
#        'un_accession', 'life_exp_days', 'population_density'],
#       dtype='object')

# %%
countries["life_expectancy_female"] > countries["life_expectancy_male"]
# Out:
# name
# Afghanistan     True
# Albania         True
# Algeria         True
# Andorra        False
# Angola          True
#                ...
# Venezuela       True
# Vietnam         True
# Yemen           True
# Zambia          True
# Zimbabwe        True
# Length: 193, dtype: bool

# %%
countries.loc["Mexico", "life_expectancy_female"] >  countries.loc["Mexico", "life_expectancy_male"]
# Out:
# True

# %%
# Is the country in Africa?
countries["world_4region"] == "africa" ###To test if this is true.
# Out:
# name
# Afghanistan    False
# Albania        False
# Algeria         True
# Andorra        False
# Angola          True
#                ...
# Venezuela      False
# Vietnam        False
# Yemen          False
# Zambia          True
# Zimbabwe        True
# Name: world_4region, Length: 193, dtype: bool

# %% [markdown]
# As in Python, conditions can be combined using operators. However, due to certain syntax requirements of Python, you need to use alternatives instead of the logical operators you know: `&` (instead of `and`),` | `(instead of` or`), and `~` (instead of `not`). Because they have different priorities than their classic little brothers, it will be better if you always use parentheses when combined with other operators.

# %%
# Where do women and men live to be over 75?
(countries["life_expectancy_male"] > 75) & (countries["life_expectancy_female"] > 75)
# Out:
# name
# Afghanistan    False
# Albania         True
# Algeria         True
# Andorra        False
# Angola         False
#                ...
# Venezuela      False
# Vietnam        False
# Yemen          False
# Zambia         False
# Zimbabwe       False
# Length: 193, dtype: bool

# %%
countries[(countries["life_expectancy_male"] > 75) & (countries["life_expectancy_female"] > 75)]
# Out:
#                       iso             world_6region world_4region  \
# name
# Albania               ALB       europe_central_asia        europe
# Algeria               DZA  middle_east_north_africa        africa
# Australia             AUS         east_asia_pacific          asia
# Austria               AUT       europe_central_asia        europe
# Bahrain               BHR  middle_east_north_africa          asia
# Belgium               BEL       europe_central_asia        europe
# Brunei                BRN         east_asia_pacific          asia
# Canada                CAN                   america      americas
# Chile                 CHL                   america      americas
# China                 CHN         east_asia_pacific          asia
# Costa Rica            CRI                   america      americas
# Cuba                  CUB                   america      americas
# Cyprus                CYP       europe_central_asia        europe
# Czechia               CZE       europe_central_asia        europe
# Denmark               DNK       europe_central_asia        europe
# Finland               FIN       europe_central_asia        europe
# France                FRA       europe_central_asia        europe
# Germany               DEU       europe_central_asia        europe
# Greece                GRC       europe_central_asia        europe
# Iceland               ISL       europe_central_asia        europe
# Iran                  IRN  middle_east_north_africa          asia
# Ireland               IRL       europe_central_asia        europe
# Israel                ISR  middle_east_north_africa          asia
# Italy                 ITA       europe_central_asia        europe
# Japan                 JPN         east_asia_pacific          asia
# Lebanon               LBN  middle_east_north_africa          asia
# Luxembourg            LUX       europe_central_asia        europe
# Maldives              MDV                south_asia          asia
# Malta                 MLT       europe_central_asia        europe
# Mexico                MEX                   america      americas
# Montenegro            MNE       europe_central_asia        europe
# Morocco               MAR  middle_east_north_africa        africa
# Netherlands           NLD       europe_central_asia        europe
# New Zealand           NZL         east_asia_pacific          asia
# Norway                NOR       europe_central_asia        europe
# Oman                  OMN  middle_east_north_africa          asia
# Panama                PAN                   america      americas
# Portugal              PRT       europe_central_asia        europe
# Qatar                 QAT  middle_east_north_africa          asia
# Singapore             SGP         east_asia_pacific          asia
# Slovenia              SVN       europe_central_asia        europe
# South Korea           KOR         east_asia_pacific          asia
# Spain                 ESP       europe_central_asia        europe
# Sweden                SWE       europe_central_asia        europe
# Switzerland           CHE       europe_central_asia        europe
# United Arab Emirates  ARE  middle_east_north_africa          asia
# United Kingdom        GBR       europe_central_asia        europe
# United States         USA                   america      americas
#
#                             income_groups  is_eu  is_oecd eu_accession  year  \
# name
# Albania               upper_middle_income  False    False          NaN  2018
# Algeria               upper_middle_income  False    False          NaN  2018
# Australia                     high_income  False     True          NaN  2018
# Austria                       high_income   True     True   1995-01-01  2018
# Bahrain                       high_income  False    False          NaN  2018
# Belgium                       high_income   True     True   1952-07-23  2018
# Brunei                        high_income  False    False          NaN  2018
# Canada                        high_income  False     True          NaN  2018
# Chile                         high_income  False     True          NaN  2018
# China                 upper_middle_income  False    False          NaN  2018
# Costa Rica            upper_middle_income  False    False          NaN  2018
# Cuba                  upper_middle_income  False    False          NaN  2018
# Cyprus                        high_income   True    False   2004-05-01  2018
# Czechia                       high_income   True     True   2004-05-01  2018
# Denmark                       high_income   True     True   1973-01-01  2018
# Finland                       high_income   True     True   1995-01-01  2018
# France                        high_income   True     True   1952-07-23  2018
# Germany                       high_income   True     True   1952-07-23  2018
# Greece                        high_income   True     True   1981-01-01  2018
# Iceland                       high_income  False     True          NaN  2018
# Iran                  upper_middle_income  False    False          NaN  2018
# Ireland                       high_income   True     True   1973-01-01  2018
# Israel                        high_income  False     True          NaN  2018
# Italy                         high_income   True     True   1952-07-23  2018
# Japan                         high_income  False     True          NaN  2018
# Lebanon               upper_middle_income  False    False          NaN  2018
# Luxembourg                    high_income   True     True   1952-07-23  2018
# Maldives              upper_middle_income  False    False          NaN  2018
# Malta                         high_income   True    False   2004-05-01  2018
# Mexico                upper_middle_income  False     True          NaN  2018
# Montenegro            upper_middle_income  False    False          NaN  2018
# Morocco               lower_middle_income  False    False          NaN  2018
# Netherlands                   high_income   True     True   1952-07-23  2018
# New Zealand                   high_income  False     True          NaN  2018
# Norway                        high_income  False     True          NaN  2018
# Oman                          high_income  False    False          NaN  2018
# Panama                upper_middle_income  False    False          NaN  2018
# Portugal                      high_income   True     True   1986-01-01  2018
# Qatar                         high_income  False    False          NaN  2018
# Singapore                     high_income  False    False          NaN  2018
# Slovenia                      high_income   True     True   2004-05-01  2018
# South Korea                   high_income  False     True          NaN  2018
# Spain                         high_income   True     True   1986-01-01  2018
# Sweden                        high_income   True     True   1995-01-01  2018
# Switzerland                   high_income  False     True          NaN  2018
# United Arab Emirates          high_income  False    False          NaN  2018
# United Kingdom                high_income   True     True   1973-01-01  2018
# United States                 high_income  False     True          NaN  2018
#
#                            area    population  ...  bmi_women  \
# name                                           ...
# Albania                 28750.0  3.238000e+06  ...      25.66
# Algeria               2381740.0  3.698000e+07  ...      26.37
# Australia             7741220.0  2.321000e+07  ...      26.88
# Austria                 83879.0  8.441000e+06  ...      25.09
# Bahrain                   771.0  1.377000e+06  ...      28.79
# Belgium                 30530.0  1.082000e+07  ...      25.14
# Brunei                   5770.0  4.198000e+05  ...      22.89
# Canada                9984670.0  3.499000e+07  ...      26.70
# Chile                  756096.0  1.757000e+07  ...      27.93
# China                 9562911.0  1.359000e+09  ...      22.91
# Costa Rica              51100.0  4.860000e+06  ...      27.03
# Cuba                   109880.0  1.124000e+07  ...      26.58
# Cyprus                   9250.0  1.141000e+06  ...      25.93
# Czechia                 78870.0  1.059000e+07  ...      26.51
# Denmark                 42922.0  5.611000e+06  ...      25.11
# Finland                338420.0  5.419000e+06  ...      25.58
# France                 549087.0  6.378000e+07  ...      24.83
# Germany                357380.0  8.180000e+07  ...      25.74
# Greece                 131960.0  1.145000e+07  ...      24.92
# Iceland                103000.0  3.320000e+05  ...      26.03
# Iran                  1745150.0  7.641000e+07  ...      27.24
# Ireland                 70280.0  4.631000e+06  ...      26.62
# Israel                  22070.0  7.819000e+06  ...      27.30
# Italy                  301340.0  6.109000e+07  ...      24.79
# Japan                  377962.0  1.263000e+08  ...      21.87
# Lebanon                 10450.0  4.324000e+06  ...      27.70
# Luxembourg               2590.0  5.300000e+05  ...      26.09
# Maldives                  300.0  3.286000e+05  ...      26.41
# Malta                     320.0  4.206000e+05  ...      27.05
# Mexico                1964380.0  1.175000e+08  ...      28.74
# Montenegro              13810.0  6.332000e+05  ...      25.70
# Morocco                446550.0  3.293000e+07  ...      26.22
# Netherlands             41540.0  1.676000e+07  ...      25.47
# New Zealand            267710.0  4.508000e+06  ...      27.37
# Norway                 385178.0  4.992000e+06  ...      25.74
# Oman                   309500.0  2.957000e+06  ...      26.67
# Panama                  75420.0  3.678000e+06  ...      27.68
# Portugal                92225.0  1.070000e+07  ...      26.18
# Qatar                   11610.0  1.977000e+06  ...      28.91
# Singapore                 719.0  5.301000e+06  ...      22.87
# Slovenia                20270.0  2.045000e+06  ...      26.58
# South Korea            100280.0  4.877000e+07  ...      23.33
# Spain                  505940.0  4.704000e+07  ...      26.31
# Sweden                 447420.0  9.546000e+06  ...      25.15
# Switzerland             41290.0  7.762000e+06  ...      24.07
# United Arab Emirates    83600.0  8.208000e+06  ...      29.61
# United Kingdom         243610.0  6.318000e+07  ...      26.94
# United States         9831510.0  3.185000e+08  ...      28.34
#
#                       car_deaths_per_100000_people  calories_per_day  \
# name
# Albania                                     5.9780            3193.0
# Algeria                                        NaN            3296.0
# Australia                                   5.3350            3276.0
# Austria                                     3.5410            3768.0
# Bahrain                                     8.1900               NaN
# Belgium                                     5.4270            3733.0
# Brunei                                     11.6700            2985.0
# Canada                                      6.3330            3494.0
# Chile                                       3.3290            2979.0
# China                                       3.5900            3108.0
# Costa Rica                                  6.3190            2848.0
# Cuba                                        2.6300            3409.0
# Cyprus                                      6.4190            2649.0
# Czechia                                     5.7200            3256.0
# Denmark                                     3.4810            3367.0
# Finland                                     3.6150            3368.0
# France                                      2.4910            3482.0
# Germany                                     3.2800            3499.0
# Greece                                      9.1750            3400.0
# Iceland                                     3.4350            3380.0
# Iran                                       26.7300            3094.0
# Ireland                                     3.7680            3600.0
# Israel                                      4.5890            3610.0
# Italy                                       3.7780            3579.0
# Japan                                       1.3810            2726.0
# Lebanon                                        NaN            3066.0
# Luxembourg                                  5.9710            3539.0
# Maldives                                   29.2700            2732.0
# Malta                                       2.2280            3378.0
# Mexico                                      9.4680            3072.0
# Montenegro                                 15.3800            3491.0
# Morocco                                    15.2500            3403.0
# Netherlands                                 2.2370            3228.0
# New Zealand                                 7.6000            3137.0
# Norway                                      3.1250            3485.0
# Oman                                           NaN            3143.0
# Panama                                      7.9860            2733.0
# Portugal                                    5.0780            3477.0
# Qatar                                      16.3500               NaN
# Singapore                                   0.7152               NaN
# Slovenia                                    5.3150            3168.0
# South Korea                                 4.3190            3334.0
# Spain                                       5.1460            3174.0
# Sweden                                      2.7370            3179.0
# Switzerland                                 2.3420            3391.0
# United Arab Emirates                       31.8500            3280.0
# United Kingdom                              3.3770            3424.0
# United States                               9.5230            3682.0
#
#                       infant_mortality  life_expectancy  \
# name
# Albania                           12.5            78.01
# Algeria                           21.9            77.86
# Australia                          3.0            82.87
# Austria                            2.9            81.84
# Bahrain                            5.3            77.18
# Belgium                            3.3            81.23
# Brunei                             8.6            77.36
# Canada                             4.3            82.16
# Chile                              7.0            80.66
# China                              9.2            76.92
# Costa Rica                         8.5            81.42
# Cuba                               4.0            79.34
# Cyprus                             2.5            80.79
# Czechia                            2.8            79.37
# Denmark                            2.9            81.10
# Finland                            1.9            82.06
# France                             3.5            82.62
# Germany                            3.1            81.25
# Greece                             3.6            81.34
# Iceland                            1.6            82.60
# Iran                              13.4            76.47
# Ireland                            3.0            81.49
# Israel                             3.2            82.41
# Italy                              2.9            82.62
# Japan                              2.0            84.17
# Lebanon                            7.1            80.45
# Luxembourg                         1.5            82.39
# Maldives                           7.4            80.08
# Malta                              5.1            81.75
# Mexico                            11.3            76.78
# Montenegro                         4.3            77.35
# Morocco                           23.7            75.46
# Netherlands                        3.2            81.92
# New Zealand                        4.7            81.77
# Norway                             2.0            82.39
# Oman                               9.9            78.06
# Panama                            14.6            79.40
# Portugal                           3.0            81.30
# Qatar                              6.8            80.71
# Singapore                          2.1            84.03
# Slovenia                           2.1            81.12
# South Korea                        2.9            81.35
# Spain                              3.5            83.23
# Sweden                             2.4            82.37
# Switzerland                        3.4            83.45
# United Arab Emirates               5.9            76.89
# United Kingdom                     3.5            81.19
# United States                      5.6            79.14
#
#                       life_expectancy_female  life_expectancy_male  \
# name
# Albania                               80.737                76.693
# Algeria                               77.784                75.279
# Australia                             85.102                81.390
# Austria                               84.249                79.585
# Bahrain                               78.293                76.318
# Belgium                               83.751                79.131
# Brunei                                79.240                75.954
# Canada                                84.509                80.859
# Chile                                 82.272                77.416
# China                                 78.163                75.096
# Costa Rica                            82.598                77.912
# Cuba                                  82.085                78.161
# Cyprus                                82.918                78.734
# Czechia                               81.858                76.148
# Denmark                               82.878                79.130
# Finland                               84.423                78.934
# France                                85.747                79.991
# Germany                               83.632                79.060
# Greece                                84.071                79.129
# Iceland                               84.480                81.669
# Iran                                  77.555                75.232
# Ireland                               83.737                79.885
# Israel                                84.382                81.140
# Italy                                 85.435                81.146
# Japan                                 87.244                80.803
# Lebanon                               81.736                78.356
# Luxembourg                            84.227                79.981
# Maldives                              79.106                77.011
# Malta                                 82.724                79.570
# Mexico                                79.880                75.120
# Montenegro                            79.760                75.051
# Morocco                               77.471                75.072
# Netherlands                           83.841                80.440
# New Zealand                           83.798                80.554
# Norway                                84.336                80.652
# Oman                                  79.919                75.791
# Panama                                81.407                75.510
# Portugal                              84.372                78.685
# Qatar                                 80.181                77.725
# Singapore                             85.337                81.362
# Slovenia                              84.017                78.499
# South Korea                           85.467                79.456
# Spain                                 86.119                80.694
# Sweden                                84.443                81.126
# Switzerland                           85.475                81.705
# United Arab Emirates                  79.081                76.870
# United Kingdom                        83.558                80.127
# United States                         81.942                77.429
#
#                       un_accession  life_exp_days population_density
# name
# Albania                 1955-12-14       28473.65         112.626087
# Algeria                 1962-10-08       28418.90          15.526464
# Australia               1945-11-01       30247.55           2.998235
# Austria                 1955-12-14       29871.60         100.633055
# Bahrain                 1971-09-21       28170.70        1785.992218
# Belgium                 1945-12-27       29648.95         354.405503
# Brunei                  1984-09-21       28236.40          72.755633
# Canada                  1945-11-09       29988.40           3.504372
# Chile                   1945-10-24       29440.90          23.237790
# China                   1945-10-24       28075.80         142.111539
# Costa Rica              1945-11-02       29718.30          95.107632
# Cuba                    1945-10-24       28959.10         102.293411
# Cyprus                  1960-09-20       29488.35         123.351351
# Czechia                 1993-01-19       28970.05         134.271586
# Denmark                 1945-10-24       29601.50         130.725502
# Finland                 1955-12-14       29951.90          16.012647
# France                  1945-10-24       30156.30         116.156456
# Germany                 1973-09-18       29656.25         228.888018
# Greece                  1945-10-25       29689.10          86.768718
# Iceland                 1946-11-19       30149.00           3.223301
# Iran                    1945-10-24       27911.55          43.784202
# Ireland                 1955-12-14       29743.85          65.893569
# Israel                  1949-05-11       30079.65         354.281831
# Italy                   1955-12-14       30156.30         202.727816
# Japan                   1956-12-18       30722.05         334.160577
# Lebanon                 1945-10-24       29364.25         413.779904
# Luxembourg              1945-10-24       30072.35         204.633205
# Maldives                1965-09-21       29229.20        1095.333333
# Malta                   1964-12-01       29838.75        1314.375000
# Mexico                  1945-11-07       28024.70          59.815311
# Montenegro              2006-06-28       28232.75          45.850833
# Morocco                 1956-11-12       27542.90          73.743142
# Netherlands             1945-12-10       29900.80         403.466538
# New Zealand             1945-10-24       29846.05          16.839117
# Norway                  1945-11-27       30072.35          12.960242
# Oman                    1971-10-07       28491.90           9.554120
# Panama                  1945-11-13       28981.00          48.766905
# Portugal                1955-12-14       29674.50         116.020602
# Qatar                   1971-09-21       29459.15         170.284238
# Singapore               1965-09-21       30670.95        7372.739917
# Slovenia                1992-05-22       29608.80         100.888012
# South Korea             1991-09-17       29692.75         486.338253
# Spain                   1955-12-14       30378.95          92.975452
# Sweden                  1946-11-19       30065.05          21.335658
# Switzerland             2002-09-10       30459.25         187.987406
# United Arab Emirates    1971-12-09       28064.85          98.181818
# United Kingdom          1945-10-24       29634.35         259.348959
# United States           1945-10-24       28886.10          32.395837
#
# [48 rows x 22 columns]

# %% [markdown]
# ## Filtering
# If you want to select rows from the table that meet a criterion, you must convert this criterion into a column of **logical values**. Then you insert this column (the column itself, not its name!) In square brackets as the index in `DataFrame`.
#
# For example, if you only want information about EU members, you can directly use the "is_eu" column, which contains logical values:

# %%
countries[countries["is_eu"]]
# Out:
#                 iso        world_6region world_4region        income_groups  \
# name
# Austria         AUT  europe_central_asia        europe          high_income
# Belgium         BEL  europe_central_asia        europe          high_income
# Bulgaria        BGR  europe_central_asia        europe  upper_middle_income
# Croatia         HRV  europe_central_asia        europe          high_income
# Cyprus          CYP  europe_central_asia        europe          high_income
# Czechia         CZE  europe_central_asia        europe          high_income
# Denmark         DNK  europe_central_asia        europe          high_income
# Estonia         EST  europe_central_asia        europe          high_income
# Finland         FIN  europe_central_asia        europe          high_income
# France          FRA  europe_central_asia        europe          high_income
# Germany         DEU  europe_central_asia        europe          high_income
# Greece          GRC  europe_central_asia        europe          high_income
# Hungary         HUN  europe_central_asia        europe  upper_middle_income
# Ireland         IRL  europe_central_asia        europe          high_income
# Italy           ITA  europe_central_asia        europe          high_income
# Latvia          LVA  europe_central_asia        europe          high_income
# Lithuania       LTU  europe_central_asia        europe          high_income
# Luxembourg      LUX  europe_central_asia        europe          high_income
# Malta           MLT  europe_central_asia        europe          high_income
# Netherlands     NLD  europe_central_asia        europe          high_income
# Poland          POL  europe_central_asia        europe          high_income
# Portugal        PRT  europe_central_asia        europe          high_income
# Romania         ROU  europe_central_asia        europe  upper_middle_income
# Slovakia        SVK  europe_central_asia        europe          high_income
# Slovenia        SVN  europe_central_asia        europe          high_income
# Spain           ESP  europe_central_asia        europe          high_income
# Sweden          SWE  europe_central_asia        europe          high_income
# United Kingdom  GBR  europe_central_asia        europe          high_income
#
#                 is_eu  is_oecd eu_accession  year      area  population  ...  \
# name                                                                     ...
# Austria          True     True   1995-01-01  2018   83879.0   8441000.0  ...
# Belgium          True     True   1952-07-23  2018   30530.0  10820000.0  ...
# Bulgaria         True    False   2007-01-01  2018  111000.0   7349000.0  ...
# Croatia          True    False   2013-01-01  2018   56590.0   4379000.0  ...
# Cyprus           True    False   2004-05-01  2018    9250.0   1141000.0  ...
# Czechia          True     True   2004-05-01  2018   78870.0  10590000.0  ...
# Denmark          True     True   1973-01-01  2018   42922.0   5611000.0  ...
# Estonia          True     True   2004-05-01  2018   45230.0   1339000.0  ...
# Finland          True     True   1995-01-01  2018  338420.0   5419000.0  ...
# France           True     True   1952-07-23  2018  549087.0  63780000.0  ...
# Germany          True     True   1952-07-23  2018  357380.0  81800000.0  ...
# Greece           True     True   1981-01-01  2018  131960.0  11450000.0  ...
# Hungary          True     True   2004-05-01  2018   93030.0   9934000.0  ...
# Ireland          True     True   1973-01-01  2018   70280.0   4631000.0  ...
# Italy            True     True   1952-07-23  2018  301340.0  61090000.0  ...
# Latvia           True     True   2004-05-01  2018   64490.0   2226000.0  ...
# Lithuania        True     True   2004-05-01  2018   65286.0   3278000.0  ...
# Luxembourg       True     True   1952-07-23  2018    2590.0    530000.0  ...
# Malta            True    False   2004-05-01  2018     320.0    420600.0  ...
# Netherlands      True     True   1952-07-23  2018   41540.0  16760000.0  ...
# Poland           True     True   2004-05-01  2018  312680.0  38330000.0  ...
# Portugal         True     True   1986-01-01  2018   92225.0  10700000.0  ...
# Romania          True    False   2007-01-01  2018  238390.0  21340000.0  ...
# Slovakia         True     True   2004-05-01  2018   49035.0   5489000.0  ...
# Slovenia         True     True   2004-05-01  2018   20270.0   2045000.0  ...
# Spain            True     True   1986-01-01  2018  505940.0  47040000.0  ...
# Sweden           True     True   1995-01-01  2018  447420.0   9546000.0  ...
# United Kingdom   True     True   1973-01-01  2018  243610.0  63180000.0  ...
#
#                 bmi_women  car_deaths_per_100000_people  calories_per_day  \
# name
# Austria             25.09                         3.541            3768.0
# Belgium             25.14                         5.427            3733.0
# Bulgaria            25.52                         9.662            2829.0
# Croatia             25.18                         6.434            3059.0
# Cyprus              25.93                         6.419            2649.0
# Czechia             26.51                         5.720            3256.0
# Denmark             25.11                         3.481            3367.0
# Estonia             25.19                         5.896            3253.0
# Finland             25.58                         3.615            3368.0
# France              24.83                         2.491            3482.0
# Germany             25.74                         3.280            3499.0
# Greece              24.92                         9.175            3400.0
# Hungary             25.98                         5.234            3037.0
# Ireland             26.62                         3.768            3600.0
# Italy               24.79                         3.778            3579.0
# Latvia              25.62                         8.275            3174.0
# Lithuania           26.01                         8.090            3417.0
# Luxembourg          26.09                         5.971            3539.0
# Malta               27.05                         2.228            3378.0
# Netherlands         25.47                         2.237            3228.0
# Poland              25.92                         7.675            3451.0
# Portugal            26.18                         5.078            3477.0
# Romania             25.22                         8.808            3358.0
# Slovakia            26.32                         6.746            2944.0
# Slovenia            26.58                         5.315            3168.0
# Spain               26.31                         5.146            3174.0
# Sweden              25.15                         2.737            3179.0
# United Kingdom      26.94                         3.377            3424.0
#
#                 infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Austria                      2.9            81.84                  84.249
# Belgium                      3.3            81.23                  83.751
# Bulgaria                     9.3            75.32                  78.485
# Croatia                      3.6            77.66                  81.167
# Cyprus                       2.5            80.79                  82.918
# Czechia                      2.8            79.37                  81.858
# Denmark                      2.9            81.10                  82.878
# Estonia                      2.3            77.66                  82.111
# Finland                      1.9            82.06                  84.423
# France                       3.5            82.62                  85.747
# Germany                      3.1            81.25                  83.632
# Greece                       3.6            81.34                  84.071
# Hungary                      5.3            75.90                  79.557
# Ireland                      3.0            81.49                  83.737
# Italy                        2.9            82.62                  85.435
# Latvia                       6.9            75.13                  79.498
# Lithuania                    3.3            75.31                  80.060
# Luxembourg                   1.5            82.39                  84.227
# Malta                        5.1            81.75                  82.724
# Netherlands                  3.2            81.92                  83.841
# Poland                       4.5            78.19                  81.732
# Portugal                     3.0            81.30                  84.372
# Romania                      9.7            75.53                  79.158
# Slovakia                     5.8            77.16                  80.511
# Slovenia                     2.1            81.12                  84.017
# Spain                        3.5            83.23                  86.119
# Sweden                       2.4            82.37                  84.443
# United Kingdom               3.5            81.19                  83.558
#
#                 life_expectancy_male  un_accession  life_exp_days  \
# name
# Austria                       79.585    1955-12-14       29871.60
# Belgium                       79.131    1945-12-27       29648.95
# Bulgaria                      71.618    1955-12-14       27491.80
# Croatia                       74.701    1992-05-22       28345.90
# Cyprus                        78.734    1960-09-20       29488.35
# Czechia                       76.148    1993-01-19       28970.05
# Denmark                       79.130    1945-10-24       29601.50
# Estonia                       73.201    1991-09-17       28345.90
# Finland                       78.934    1955-12-14       29951.90
# France                        79.991    1945-10-24       30156.30
# Germany                       79.060    1973-09-18       29656.25
# Greece                        79.129    1945-10-25       29689.10
# Hungary                       72.610    1955-12-14       27703.50
# Ireland                       79.885    1955-12-14       29743.85
# Italy                         81.146    1955-12-14       30156.30
# Latvia                        69.882    1991-09-17       27422.45
# Lithuania                     69.554    1991-09-17       27488.15
# Luxembourg                    79.981    1945-10-24       30072.35
# Malta                         79.570    1964-12-01       29838.75
# Netherlands                   80.440    1945-12-10       29900.80
# Poland                        74.043    1945-10-24       28539.35
# Portugal                      78.685    1955-12-14       29674.50
# Romania                       72.265    1955-12-14       27568.45
# Slovakia                      73.589    1993-01-19       28163.40
# Slovenia                      78.499    1992-05-22       29608.80
# Spain                         80.694    1955-12-14       30378.95
# Sweden                        81.126    1946-11-19       30065.05
# United Kingdom                80.127    1945-10-24       29634.35
#
#                population_density
# name
# Austria                100.633055
# Belgium                354.405503
# Bulgaria                66.207207
# Croatia                 77.381163
# Cyprus                 123.351351
# Czechia                134.271586
# Denmark                130.725502
# Estonia                 29.604245
# Finland                 16.012647
# France                 116.156456
# Germany                228.888018
# Greece                  86.768718
# Hungary                106.782758
# Ireland                 65.893569
# Italy                  202.727816
# Latvia                  34.516979
# Lithuania               50.209846
# Luxembourg             204.633205
# Malta                 1314.375000
# Netherlands            403.466538
# Poland                 122.585391
# Portugal               116.020602
# Romania                 89.517178
# Slovakia               111.940451
# Slovenia               100.888012
# Spain                   92.975452
# Sweden                  21.335658
# United Kingdom         259.348959
#
# [28 rows x 22 columns]

# %% [markdown]
# You don't have to use an existing column in the table - just modify the condition to return a Series of logical values:

# %%
# Small countries
countries[countries["population"] < 100_000] # Underlining helps to separate thousands visually
# Out:
#                        iso        world_6region world_4region  \
# name
# Andorra                AND  europe_central_asia        europe
# Antigua and Barbuda    ATG              america      americas
# Dominica               DMA              america      americas
# Liechtenstein          LIE  europe_central_asia        europe
# Marshall Islands       MHL    east_asia_pacific          asia
# Monaco                 MCO  europe_central_asia        europe
# Nauru                  NRU    east_asia_pacific          asia
# Palau                  PLW    east_asia_pacific          asia
# Saint Kitts and Nevis  KNA              america      americas
# San Marino             SMR  europe_central_asia        europe
# Seychelles             SYC   sub_saharan_africa        africa
# Tuvalu                 TUV    east_asia_pacific          asia
#
#                              income_groups  is_eu  is_oecd eu_accession  year  \
# name
# Andorra                        high_income  False    False          NaN  2017
# Antigua and Barbuda            high_income  False    False          NaN  2018
# Dominica               upper_middle_income  False    False          NaN  2017
# Liechtenstein                  high_income  False    False          NaN  2017
# Marshall Islands       upper_middle_income  False    False          NaN  2017
# Monaco                         high_income  False    False          NaN  2017
# Nauru                                  NaN  False    False          NaN  2015
# Palau                  upper_middle_income  False    False          NaN  2017
# Saint Kitts and Nevis          high_income  False    False          NaN  2017
# San Marino                     high_income  False    False          NaN  2017
# Seychelles             upper_middle_income  False    False          NaN  2018
# Tuvalu                 upper_middle_income  False    False          NaN  2017
#
#                         area  population  ...  bmi_women  \
# name                                      ...
# Andorra                470.0     88910.0  ...      26.43
# Antigua and Barbuda    440.0     91400.0  ...      27.51
# Dominica               750.0     67700.0  ...      28.78
# Liechtenstein          160.0     36870.0  ...        NaN
# Marshall Islands       180.0     56690.0  ...      31.39
# Monaco                   2.0     35460.0  ...        NaN
# Nauru                   20.0     10440.0  ...      35.02
# Palau                  460.0     20920.0  ...      31.85
# Saint Kitts and Nevis  260.0     54340.0  ...      30.51
# San Marino              60.0     32160.0  ...        NaN
# Seychelles             460.0     87420.0  ...      27.97
# Tuvalu                  30.0      9888.0  ...        NaN
#
#                        car_deaths_per_100000_people  calories_per_day  \
# name
# Andorra                                         NaN               NaN
# Antigua and Barbuda                             NaN            2417.0
# Dominica                                        NaN            2931.0
# Liechtenstein                                   NaN               NaN
# Marshall Islands                              1.800               NaN
# Monaco                                          NaN               NaN
# Nauru                                           NaN               NaN
# Palau                                        10.730               NaN
# Saint Kitts and Nevis                           NaN            2492.0
# San Marino                                    5.946               NaN
# Seychelles                                   11.700               NaN
# Tuvalu                                          NaN               NaN
#
#                        infant_mortality  life_expectancy  \
# name
# Andorra                            2.10            82.55
# Antigua and Barbuda                5.80            77.60
# Dominica                          19.60            73.01
# Liechtenstein                      1.76              NaN
# Marshall Islands                  29.60            65.00
# Monaco                             2.80              NaN
# Nauru                             29.10              NaN
# Palau                             14.20              NaN
# Saint Kitts and Nevis              8.40              NaN
# San Marino                         2.60              NaN
# Seychelles                        11.70            74.23
# Tuvalu                            22.80              NaN
#
#                        life_expectancy_female  life_expectancy_male  \
# name
# Andorra                                   NaN                   NaN
# Antigua and Barbuda                    79.028                74.154
# Dominica                                  NaN                   NaN
# Liechtenstein                             NaN                   NaN
# Marshall Islands                          NaN                   NaN
# Monaco                                    NaN                   NaN
# Nauru                                     NaN                   NaN
# Palau                                     NaN                   NaN
# Saint Kitts and Nevis                     NaN                   NaN
# San Marino                                NaN                   NaN
# Seychelles                             78.730                69.693
# Tuvalu                                    NaN                   NaN
#
#                        un_accession  life_exp_days population_density
# name
# Andorra                  1993-07-28       30130.75         189.170213
# Antigua and Barbuda      1981-11-11       28324.00         207.727273
# Dominica                 1978-12-18       26648.65          90.266667
# Liechtenstein            1990-09-18            NaN         230.437500
# Marshall Islands         1991-09-17       23725.00         314.944444
# Monaco                   1993-05-28            NaN       17730.000000
# Nauru                    1999-09-14            NaN         522.000000
# Palau                    1994-12-15            NaN          45.478261
# Saint Kitts and Nevis    1983-09-23            NaN         209.000000
# San Marino               1992-03-02            NaN         536.000000
# Seychelles               1976-09-21       27093.95         190.043478
# Tuvalu                   2000-09-05            NaN         329.600000
#
# [12 rows x 22 columns]

# %% [markdown]
# ... and of course combinations:

# %%
# Poorer EU countries
countries[countries["is_eu"] & (countries["income_groups"] != "high_income")]
# Out:
#           iso        world_6region world_4region        income_groups  is_eu  \
# name
# Bulgaria  BGR  europe_central_asia        europe  upper_middle_income   True
# Hungary   HUN  europe_central_asia        europe  upper_middle_income   True
# Romania   ROU  europe_central_asia        europe  upper_middle_income   True
#
#           is_oecd eu_accession  year      area  population  ...  bmi_women  \
# name                                                        ...
# Bulgaria    False   2007-01-01  2018  111000.0   7349000.0  ...      25.52
# Hungary      True   2004-05-01  2018   93030.0   9934000.0  ...      25.98
# Romania     False   2007-01-01  2018  238390.0  21340000.0  ...      25.22
#
#           car_deaths_per_100000_people  calories_per_day  infant_mortality  \
# name
# Bulgaria                         9.662            2829.0               9.3
# Hungary                          5.234            3037.0               5.3
# Romania                          8.808            3358.0               9.7
#
#           life_expectancy  life_expectancy_female  life_expectancy_male  \
# name
# Bulgaria            75.32                  78.485                71.618
# Hungary             75.90                  79.557                72.610
# Romania             75.53                  79.158                72.265
#
#           un_accession  life_exp_days population_density
# name
# Bulgaria    1955-12-14       27491.80          66.207207
# Hungary     1955-12-14       27703.50         106.782758
# Romania     1955-12-14       27568.45          89.517178
#
# [3 rows x 22 columns]

# %%
# Which OECD countries have a life expectancy of less than 78 years?
countries[(countries["is_oecd"]) & (countries["life_expectancy"] < 78)]
# Out:
#            iso        world_6region world_4region        income_groups  is_eu  \
# name
# Estonia    EST  europe_central_asia        europe          high_income   True
# Hungary    HUN  europe_central_asia        europe  upper_middle_income   True
# Latvia     LVA  europe_central_asia        europe          high_income   True
# Lithuania  LTU  europe_central_asia        europe          high_income   True
# Mexico     MEX              america      americas  upper_middle_income  False
# Slovakia   SVK  europe_central_asia        europe          high_income   True
#
#            is_oecd eu_accession  year       area   population  ...  bmi_women  \
# name                                                           ...
# Estonia       True   2004-05-01  2018    45230.0    1339000.0  ...      25.19
# Hungary       True   2004-05-01  2018    93030.0    9934000.0  ...      25.98
# Latvia        True   2004-05-01  2018    64490.0    2226000.0  ...      25.62
# Lithuania     True   2004-05-01  2018    65286.0    3278000.0  ...      26.01
# Mexico        True          NaN  2018  1964380.0  117500000.0  ...      28.74
# Slovakia      True   2004-05-01  2018    49035.0    5489000.0  ...      26.32
#
#            car_deaths_per_100000_people  calories_per_day  infant_mortality  \
# name
# Estonia                           5.896            3253.0               2.3
# Hungary                           5.234            3037.0               5.3
# Latvia                            8.275            3174.0               6.9
# Lithuania                         8.090            3417.0               3.3
# Mexico                            9.468            3072.0              11.3
# Slovakia                          6.746            2944.0               5.8
#
#            life_expectancy  life_expectancy_female  life_expectancy_male  \
# name
# Estonia              77.66                  82.111                73.201
# Hungary              75.90                  79.557                72.610
# Latvia               75.13                  79.498                69.882
# Lithuania            75.31                  80.060                69.554
# Mexico               76.78                  79.880                75.120
# Slovakia             77.16                  80.511                73.589
#
#            un_accession  life_exp_days population_density
# name
# Estonia      1991-09-17       28345.90          29.604245
# Hungary      1955-12-14       27703.50         106.782758
# Latvia       1991-09-17       27422.45          34.516979
# Lithuania    1991-09-17       27488.15          50.209846
# Mexico       1945-11-07       28024.70          59.815311
# Slovakia     1993-01-19       28163.40         111.940451
#
# [6 rows x 22 columns]

# %% [markdown]
# Because this method of filtering is a bit awkward, there is also a `query` method (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html) that allows you to select rows based on a string that describes some (in)equality of column names and numeric values (which is often the case, but sometimes it doesn&#39;t have to).

# %%
# Really big countries (population over 100 million)
countries.query("population > 100_000_000")
# Out:
#                iso        world_6region world_4region        income_groups  \
# name
# Bangladesh     BGD           south_asia          asia           low_income
# Brazil         BRA              america      americas  upper_middle_income
# China          CHN    east_asia_pacific          asia  upper_middle_income
# India          IND           south_asia          asia  lower_middle_income
# Indonesia      IDN    east_asia_pacific          asia  lower_middle_income
# Japan          JPN    east_asia_pacific          asia          high_income
# Mexico         MEX              america      americas  upper_middle_income
# Nigeria        NGA   sub_saharan_africa        africa  lower_middle_income
# Pakistan       PAK           south_asia          asia  lower_middle_income
# Russia         RUS  europe_central_asia        europe          high_income
# United States  USA              america      americas          high_income
#
#                is_eu  is_oecd eu_accession  year        area    population  \
# name
# Bangladesh     False    False          NaN  2018    147630.0  1.544000e+08
# Brazil         False    False          NaN  2018   8515770.0  2.001000e+08
# China          False    False          NaN  2018   9562911.0  1.359000e+09
# India          False    False          NaN  2018   3287259.0  1.275000e+09
# Indonesia      False    False          NaN  2018   1910931.0  2.472000e+08
# Japan          False     True          NaN  2018    377962.0  1.263000e+08
# Mexico         False     True          NaN  2018   1964380.0  1.175000e+08
# Nigeria        False    False          NaN  2018    923770.0  1.709000e+08
# Pakistan       False    False          NaN  2018    796100.0  1.832000e+08
# Russia         False    False          NaN  2018  17098250.0  1.426000e+08
# United States  False     True          NaN  2018   9831510.0  3.185000e+08
#
#                ...  bmi_women  car_deaths_per_100000_people  calories_per_day  \
# name           ...
# Bangladesh     ...      20.55                         4.401            2450.0
# Brazil         ...      25.99                         1.872            3263.0
# China          ...      22.91                         3.590            3108.0
# India          ...      21.31                         3.034            2459.0
# Indonesia      ...      22.99                         1.232            2777.0
# Japan          ...      21.87                         1.381            2726.0
# Mexico         ...      28.74                         9.468            3072.0
# Nigeria        ...      23.67                           NaN            2700.0
# Pakistan       ...      23.45                           NaN            2440.0
# Russia         ...      27.21                        14.380            3361.0
# United States  ...      28.34                         9.523            3682.0
#
#                infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Bangladesh                 30.7            73.41                  74.937
# Brazil                     14.6            75.70                  79.527
# China                       9.2            76.92                  78.163
# India                      37.9            69.10                  70.678
# Indonesia                  22.8            72.03                  71.742
# Japan                       2.0            84.17                  87.244
# Mexico                     11.3            76.78                  79.880
# Nigeria                    69.4            66.14                  55.158
# Pakistan                   65.8            67.96                  67.869
# Russia                      8.2            71.07                  76.882
# United States               5.6            79.14                  81.942
#
#                life_expectancy_male  un_accession  life_exp_days  \
# name
# Bangladesh                   71.484    1974-09-17       26794.65
# Brazil                       72.340    1945-10-24       27630.50
# China                        75.096    1945-10-24       28075.80
# India                        67.538    1945-10-30       25221.50
# Indonesia                    67.426    1950-09-28       26290.95
# Japan                        80.803    1956-12-18       30722.05
# Mexico                       75.120    1945-11-07       28024.70
# Nigeria                      53.512    1960-10-07       24141.10
# Pakistan                     65.750    1947-09-30       24805.40
# Russia                       65.771    1945-10-24       25940.55
# United States                77.429    1945-10-24       28886.10
#
#               population_density
# name
# Bangladesh           1045.857888
# Brazil                 23.497582
# China                 142.111539
# India                 387.861133
# Indonesia             129.361029
# Japan                 334.160577
# Mexico                 59.815311
# Nigeria               185.002760
# Pakistan              230.121844
# Russia                  8.340035
# United States          32.395837
#
# [11 rows x 22 columns]

# %%
# In which EU countries people tend to consume a lot?

countries.query("is_eu & (calories_per_day > 3500)")
# Out:
#             iso        world_6region world_4region income_groups  is_eu  \
# name
# Austria     AUT  europe_central_asia        europe   high_income   True
# Belgium     BEL  europe_central_asia        europe   high_income   True
# Ireland     IRL  europe_central_asia        europe   high_income   True
# Italy       ITA  europe_central_asia        europe   high_income   True
# Luxembourg  LUX  europe_central_asia        europe   high_income   True
#
#             is_oecd eu_accession  year      area  population  ...  bmi_women  \
# name                                                          ...
# Austria        True   1995-01-01  2018   83879.0   8441000.0  ...      25.09
# Belgium        True   1952-07-23  2018   30530.0  10820000.0  ...      25.14
# Ireland        True   1973-01-01  2018   70280.0   4631000.0  ...      26.62
# Italy          True   1952-07-23  2018  301340.0  61090000.0  ...      24.79
# Luxembourg     True   1952-07-23  2018    2590.0    530000.0  ...      26.09
#
#             car_deaths_per_100000_people  calories_per_day  infant_mortality  \
# name
# Austria                            3.541            3768.0               2.9
# Belgium                            5.427            3733.0               3.3
# Ireland                            3.768            3600.0               3.0
# Italy                              3.778            3579.0               2.9
# Luxembourg                         5.971            3539.0               1.5
#
#             life_expectancy  life_expectancy_female  life_expectancy_male  \
# name
# Austria               81.84                  84.249                79.585
# Belgium               81.23                  83.751                79.131
# Ireland               81.49                  83.737                79.885
# Italy                 82.62                  85.435                81.146
# Luxembourg            82.39                  84.227                79.981
#
#             un_accession  life_exp_days population_density
# name
# Austria       1955-12-14       29871.60         100.633055
# Belgium       1945-12-27       29648.95         354.405503
# Ireland       1955-12-14       29743.85          65.893569
# Italy         1955-12-14       30156.30         202.727816
# Luxembourg    1945-10-24       30072.35         204.633205
#
# [5 rows x 22 columns]

# %%
oced = countries[(countries["is_oecd"]) & (countries["life_expectancy"] < 78)]

# %%
oced.head()
# Out:
#            iso        world_6region world_4region        income_groups  is_eu  \
# name
# Estonia    EST  europe_central_asia        europe          high_income   True
# Hungary    HUN  europe_central_asia        europe  upper_middle_income   True
# Latvia     LVA  europe_central_asia        europe          high_income   True
# Lithuania  LTU  europe_central_asia        europe          high_income   True
# Mexico     MEX              america      americas  upper_middle_income  False
#
#            is_oecd eu_accession  year       area   population  ...  bmi_women  \
# name                                                           ...
# Estonia       True   2004-05-01  2018    45230.0    1339000.0  ...      25.19
# Hungary       True   2004-05-01  2018    93030.0    9934000.0  ...      25.98
# Latvia        True   2004-05-01  2018    64490.0    2226000.0  ...      25.62
# Lithuania     True   2004-05-01  2018    65286.0    3278000.0  ...      26.01
# Mexico        True          NaN  2018  1964380.0  117500000.0  ...      28.74
#
#            car_deaths_per_100000_people  calories_per_day  infant_mortality  \
# name
# Estonia                           5.896            3253.0               2.3
# Hungary                           5.234            3037.0               5.3
# Latvia                            8.275            3174.0               6.9
# Lithuania                         8.090            3417.0               3.3
# Mexico                            9.468            3072.0              11.3
#
#            life_expectancy  life_expectancy_female  life_expectancy_male  \
# name
# Estonia              77.66                  82.111                73.201
# Hungary              75.90                  79.557                72.610
# Latvia               75.13                  79.498                69.882
# Lithuania            75.31                  80.060                69.554
# Mexico               76.78                  79.880                75.120
#
#            un_accession  life_exp_days population_density
# name
# Estonia      1991-09-17       28345.90          29.604245
# Hungary      1955-12-14       27703.50         106.782758
# Latvia       1991-09-17       27422.45          34.516979
# Lithuania    1991-09-17       27488.15          50.209846
# Mexico       1945-11-07       28024.70          59.815311
#
# [5 rows x 22 columns]

# %%
oced ["world_4region"]
# Out:
# name
# Estonia        europe
# Hungary        europe
# Latvia         europe
# Lithuania      europe
# Mexico       americas
# Slovakia       europe
# Name: world_4region, dtype: object

# %% [markdown]
# > ### Task
# 1. Which only country in Africa belongs to the high-income group?
# 2. In which countries do you drink a lot (use any criterion)

# %%
countries["world_4region"].unique()
# Out:
# array(['asia', 'europe', 'africa', 'americas'], dtype=object)

# %%
countries["income_groups"].unique()
# Out:
# ['low_income', 'upper_middle_income', 'high_income', 'lower_middle_income', NaN]
# Categories (4, object): ['high_income', 'low_income', 'lower_middle_income', 'upper_middle_income']

# %%
countries[(countries["world_4region"] == "africa") & (countries["income_groups"] == "high_income")]
# Out:
#                    iso       world_6region world_4region income_groups  is_eu  \
# name
# Equatorial Guinea  GNQ  sub_saharan_africa        africa   high_income  False
#
#                    is_oecd eu_accession  year     area  population  ...  \
# name                                                                ...
# Equatorial Guinea    False          NaN  2018  28050.0    761000.0  ...
#
#                    bmi_women  car_deaths_per_100000_people  calories_per_day  \
# name
# Equatorial Guinea      24.53                           NaN               NaN
#
#                    infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Equatorial Guinea              68.2            66.13                  59.653
#
#                    life_expectancy_male  un_accession  life_exp_days  \
# name
# Equatorial Guinea                56.979    1968-11-12       24137.45
#
#                   population_density
# name
# Equatorial Guinea          27.130125
#
# [1 rows x 22 columns]

# %%
countries.query("(world_4region == africa)")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     199             if self.has_resolvers:
# --> 200                 return self.resolvers[key]
#     201
#
# ~/miniconda3/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# ~/miniconda3/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'africa'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     210                 # e.g., df[df > 0]
# --> 211                 return self.temps[key]
#     212             except KeyError as err:
#
# KeyError: 'africa'
#
# The above exception was the direct cause of the following exception:
#
# UndefinedVariableError                    Traceback (most recent call last)
# /tmp/ipykernel_27784/485654701.py in <module>
# ----> 1 countries.query("(world_4region == africa)")
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/frame.py in query(self, expr, inplace, **kwargs)
#    4058         kwargs["level"] = kwargs.pop("level", 0) + 1
#    4059         kwargs["target"] = None
# -> 4060         res = self.eval(expr, **kwargs)
#    4061
#    4062         try:
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/frame.py in eval(self, expr, inplace, **kwargs)
#    4189         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    4190
# -> 4191         return _eval(expr, inplace=inplace, **kwargs)
#    4192
#    4193     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     346         )
#     347
# --> 348         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     349
#     350         # construct the engine and evaluate the parsed expression
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in __init__(self, expr, engine, parser, env, level)
#     804         self.parser = parser
#     805         self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 806         self.terms = self.parse()
#     807
#     808     @property
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in parse(self)
#     823         Parse an expression.
#     824         """
# --> 825         return self._visitor.visit(self.expr)
#     826
#     827     @property
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = "visit_" + type(node).__name__
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Module(self, node, **kwargs)
#     415             raise SyntaxError("only a single expression is allowed")
#     416         expr = node.body[0]
# --> 417         return self.visit(expr, **kwargs)
#     418
#     419     def visit_Expr(self, node, **kwargs):
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = "visit_" + type(node).__name__
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Expr(self, node, **kwargs)
#     418
#     419     def visit_Expr(self, node, **kwargs):
# --> 420         return self.visit(node.value, **kwargs)
#     421
#     422     def _rewrite_membership_op(self, node, left, right):
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = "visit_" + type(node).__name__
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Compare(self, node, **kwargs)
#     716             op = self.translate_In(ops[0])
#     717             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 718             return self.visit(binop)
#     719
#     720         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = "visit_" + type(node).__name__
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_BinOp(self, node, **kwargs)
#     530
#     531     def visit_BinOp(self, node, **kwargs):
# --> 532         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     533         left, right = self._maybe_downcast_constants(left, right)
#     534         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     452             left = self.visit(node.left, side="left")
#     453         if right is None:
# --> 454             right = self.visit(node.right, side="right")
#     455         op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     456         return op, op_class, left, right
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit(self, node, **kwargs)
#     409         method = "visit_" + type(node).__name__
#     410         visitor = getattr(self, method)
# --> 411         return visitor(node, **kwargs)
#     412
#     413     def visit_Module(self, node, **kwargs):
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/expr.py in visit_Name(self, node, **kwargs)
#     543
#     544     def visit_Name(self, node, **kwargs):
# --> 545         return self.term_type(node.id, self.env, **kwargs)
#     546
#     547     def visit_NameConstant(self, node, **kwargs):
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/ops.py in __init__(self, name, env, side, encoding)
#      96         tname = str(name)
#      97         self.is_local = tname.startswith(LOCAL_TAG) or tname in DEFAULT_GLOBALS
# ---> 98         self._value = self._resolve_name()
#      99         self.encoding = encoding
#     100
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/ops.py in _resolve_name(self)
#     113
#     114     def _resolve_name(self):
# --> 115         res = self.env.resolve(self.local_name, is_local=self.is_local)
#     116         self.update(res)
#     117
#
# ~/pyladies_vienna_data_course/myvenv/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     214                 from pandas.core.computation.ops import UndefinedVariableError
#     215
# --> 216                 raise UndefinedVariableError(key, is_local) from err
#     217
#     218     def swapkey(self, old_key: str, new_key: str, new_value=None) -> None:
#
# UndefinedVariableError: name 'africa' is not defined

# %%
countries.columns
# Out:
# Index(['iso', 'world_6region', 'world_4region', 'income_groups', 'is_eu',
#        'is_oecd', 'eu_accession', 'year', 'area', 'population',
#        'alcohol_adults', 'bmi_men', 'bmi_women',
#        'car_deaths_per_100000_people', 'calories_per_day', 'infant_mortality',
#        'life_expectancy', 'life_expectancy_female', 'life_expectancy_male',
#        'un_accession', 'life_exp_days', 'population_density'],
#       dtype='object')

# %%
countries[(countries["alcohol_adults"] > 15) & (countries["income_groups"] != "low_income")]
# Out:
#              iso        world_6region world_4region        income_groups  \
# name
# Belarus      BLR  europe_central_asia        europe  upper_middle_income
# Czechia      CZE  europe_central_asia        europe          high_income
# Estonia      EST  europe_central_asia        europe          high_income
# Hungary      HUN  europe_central_asia        europe  upper_middle_income
# Lithuania    LTU  europe_central_asia        europe          high_income
# Moldova      MDA  europe_central_asia        europe  lower_middle_income
# Romania      ROU  europe_central_asia        europe  upper_middle_income
# Russia       RUS  europe_central_asia        europe          high_income
# South Korea  KOR    east_asia_pacific          asia          high_income
# Ukraine      UKR  europe_central_asia        europe  lower_middle_income
#
#              is_eu  is_oecd eu_accession  year        area   population  ...  \
# name                                                                     ...
# Belarus      False    False          NaN  2018    207600.0    9498000.0  ...
# Czechia       True     True   2004-05-01  2018     78870.0   10590000.0  ...
# Estonia       True     True   2004-05-01  2018     45230.0    1339000.0  ...
# Hungary       True     True   2004-05-01  2018     93030.0    9934000.0  ...
# Lithuania     True     True   2004-05-01  2018     65286.0    3278000.0  ...
# Moldova      False    False          NaN  2018     33850.0    3496000.0  ...
# Romania       True    False   2007-01-01  2018    238390.0   21340000.0  ...
# Russia       False    False          NaN  2018  17098250.0  142600000.0  ...
# South Korea  False     True          NaN  2018    100280.0   48770000.0  ...
# Ukraine      False    False          NaN  2018    603550.0   44700000.0  ...
#
#              bmi_women  car_deaths_per_100000_people  calories_per_day  \
# name
# Belarus          26.64                         8.454            3250.0
# Czechia          26.51                         5.720            3256.0
# Estonia          25.19                         5.896            3253.0
# Hungary          25.98                         5.234            3037.0
# Lithuania        26.01                         8.090            3417.0
# Moldova          27.06                         5.529            2714.0
# Romania          25.22                         8.808            3358.0
# Russia           27.21                        14.380            3361.0
# South Korea      23.33                         4.319            3334.0
# Ukraine          26.23                         8.771            3138.0
#
#              infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Belarus                   3.4            73.76                  78.583
# Czechia                   2.8            79.37                  81.858
# Estonia                   2.3            77.66                  82.111
# Hungary                   5.3            75.90                  79.557
# Lithuania                 3.3            75.31                  80.060
# Moldova                  13.6            72.41                  76.090
# Romania                   9.7            75.53                  79.158
# Russia                    8.2            71.07                  76.882
# South Korea               2.9            81.35                  85.467
# Ukraine                   7.7            72.29                  77.067
#
#              life_expectancy_male  un_accession  life_exp_days  \
# name
# Belarus                    67.693    1945-10-24       26922.40
# Czechia                    76.148    1993-01-19       28970.05
# Estonia                    73.201    1991-09-17       28345.90
# Hungary                    72.610    1955-12-14       27703.50
# Lithuania                  69.554    1991-09-17       27488.15
# Moldova                    67.544    1992-03-02       26429.65
# Romania                    72.265    1955-12-14       27568.45
# Russia                     65.771    1945-10-24       25940.55
# South Korea                79.456    1991-09-17       29692.75
# Ukraine                    67.246    1945-10-24       26385.85
#
#             population_density
# name
# Belarus              45.751445
# Czechia             134.271586
# Estonia              29.604245
# Hungary             106.782758
# Lithuania            50.209846
# Moldova             103.279173
# Romania              89.517178
# Russia                8.340035
# South Korea         486.338253
# Ukraine              74.061801
#
# [10 rows x 22 columns]

# %% [markdown]
# ## Sorting

# %% [markdown]
# In the introductory `pandas` lesson, we have already shown how to sort rows using the `sort_index` method (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_index.html) according to the index. Since the `countries` are already aligned, let&#39;s try it again on the planets:

# %%
planets.sort_index()
# Out:
#         symbol  equatorian_diameter  orbital_period  moons has_rings
# name
# Earth        ⊕                 1.00            1.00    1.0     False
# Jupiter      ♃                 5.20           11.86   79.0      True
# Mars         ♂                 1.52            1.88    2.0     False
# Mercury      ☿                 0.39            0.24    0.0     False
# Neptune      ♆                30.06          164.80   14.0      True
# Pluto      NaN                  NaN             NaN    NaN       NaN
# Saturn       ♄                 9.54           29.46   82.0      True
# Uranus       ♅                19.22           84.01   27.0      True
# Venus        ♀                 0.72            0.62    0.0     False

# %% [markdown]
# The `sort_values` method is used to sort the values in the `Series` (https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html):

# %%
# 10 countries with the smallest population THIS IS DEFAULT... the ascending true
countries["population"].sort_values(ascending=True).head(10)
# Out:
# name
# Tuvalu                    9888.0
# Nauru                    10440.0
# Palau                    20920.0
# San Marino               32160.0
# Monaco                   35460.0
# Liechtenstein            36870.0
# Saint Kitts and Nevis    54340.0
# Marshall Islands         56690.0
# Dominica                 67700.0
# Seychelles               87420.0
# Name: population, dtype: float64

# %% [markdown]
# The optional argument `ascending` tells us which way to go. The default value is `True`, so changing to`False` will sort from largest to smallest:

# %%
# The largest 10 countries by area
countries["area"].sort_values(ascending=False).head(10)
# Out:
# name
# Russia           17098250.0
# Canada            9984670.0
# United States     9831510.0
# China             9562911.0
# Brazil            8515770.0
# Australia         7741220.0
# India             3287259.0
# Argentina         2780400.0
# Kazakhstan        2724902.0
# Algeria           2381740.0
# Name: area, dtype: float64

# %% [markdown]
# In the case of a table, the first argument should be the name of the column (or columns) by which we want to sort:

# %%
# 10 countries with the highest alcohol consumption per capita
countries.sort_values("alcohol_adults", ascending=False).head(10)
# Out:
#              iso        world_6region world_4region        income_groups  \
# name
# Moldova      MDA  europe_central_asia        europe  lower_middle_income
# South Korea  KOR    east_asia_pacific          asia          high_income
# Belarus      BLR  europe_central_asia        europe  upper_middle_income
# North Korea  PRK    east_asia_pacific          asia           low_income
# Ukraine      UKR  europe_central_asia        europe  lower_middle_income
# Estonia      EST  europe_central_asia        europe          high_income
# Czechia      CZE  europe_central_asia        europe          high_income
# Uganda       UGA   sub_saharan_africa        africa           low_income
# Lithuania    LTU  europe_central_asia        europe          high_income
# Russia       RUS  europe_central_asia        europe          high_income
#
#              is_eu  is_oecd eu_accession  year        area   population  ...  \
# name                                                                     ...
# Moldova      False    False          NaN  2018     33850.0    3496000.0  ...
# South Korea  False     True          NaN  2018    100280.0   48770000.0  ...
# Belarus      False    False          NaN  2018    207600.0    9498000.0  ...
# North Korea  False    False          NaN  2018    120540.0   24650000.0  ...
# Ukraine      False    False          NaN  2018    603550.0   44700000.0  ...
# Estonia       True     True   2004-05-01  2018     45230.0    1339000.0  ...
# Czechia       True     True   2004-05-01  2018     78870.0   10590000.0  ...
# Uganda       False    False          NaN  2018    241550.0   36760000.0  ...
# Lithuania     True     True   2004-05-01  2018     65286.0    3278000.0  ...
# Russia       False    False          NaN  2018  17098250.0  142600000.0  ...
#
#              bmi_women  car_deaths_per_100000_people  calories_per_day  \
# name
# Moldova          27.06                         5.529            2714.0
# South Korea      23.33                         4.319            3334.0
# Belarus          26.64                         8.454            3250.0
# North Korea      21.25                           NaN            2094.0
# Ukraine          26.23                         8.771            3138.0
# Estonia          25.19                         5.896            3253.0
# Czechia          26.51                         5.720            3256.0
# Uganda           22.48                        13.690            2130.0
# Lithuania        26.01                         8.090            3417.0
# Russia           27.21                        14.380            3361.0
#
#              infant_mortality  life_expectancy  life_expectancy_female  \
# name
# Moldova                  13.6            72.41                  76.090
# South Korea               2.9            81.35                  85.467
# Belarus                   3.4            73.76                  78.583
# North Korea              19.7            71.13                  75.512
# Ukraine                   7.7            72.29                  77.067
# Estonia                   2.3            77.66                  82.111
# Czechia                   2.8            79.37                  81.858
# Uganda                   37.7            62.86                  62.667
# Lithuania                 3.3            75.31                  80.060
# Russia                    8.2            71.07                  76.882
#
#              life_expectancy_male  un_accession  life_exp_days  \
# name
# Moldova                    67.544    1992-03-02       26429.65
# South Korea                79.456    1991-09-17       29692.75
# Belarus                    67.693    1945-10-24       26922.40
# North Korea                68.450    1991-09-17       25962.45
# Ukraine                    67.246    1945-10-24       26385.85
# Estonia                    73.201    1991-09-17       28345.90
# Czechia                    76.148    1993-01-19       28970.05
# Uganda                     58.252    1962-10-25       22943.90
# Lithuania                  69.554    1991-09-17       27488.15
# Russia                     65.771    1945-10-24       25940.55
#
#             population_density
# name
# Moldova             103.279173
# South Korea         486.338253
# Belarus              45.751445
# North Korea         204.496433
# Ukraine              74.061801
# Estonia              29.604245
# Czechia             134.271586
# Uganda              152.183813
# Lithuania            50.209846
# Russia                8.340035
#
# [10 rows x 22 columns]

# %% [markdown]
# 💡 In the next cell, the entire code is enclosed in parentheses. This allowed us to stretch one expression into several lines so that we could comment on its parts properly.

# %%
(
    # Only EU countries
    countries[countries["is_eu"]]
    
    # Sort first by date of EU accession, then by UN accession
    .sort_values(["eu_accession", "un_accession"])

    # Show only those two columns
    [["eu_accession", "un_accession"]]
)
# Out:
#                eu_accession un_accession
# name
# France           1952-07-23   1945-10-24
# Luxembourg       1952-07-23   1945-10-24
# Netherlands      1952-07-23   1945-12-10
# Belgium          1952-07-23   1945-12-27
# Italy            1952-07-23   1955-12-14
# Germany          1952-07-23   1973-09-18
# Denmark          1973-01-01   1945-10-24
# United Kingdom   1973-01-01   1945-10-24
# Ireland          1973-01-01   1955-12-14
# Greece           1981-01-01   1945-10-25
# Portugal         1986-01-01   1955-12-14
# Spain            1986-01-01   1955-12-14
# Sweden           1995-01-01   1946-11-19
# Austria          1995-01-01   1955-12-14
# Finland          1995-01-01   1955-12-14
# Poland           2004-05-01   1945-10-24
# Hungary          2004-05-01   1955-12-14
# Cyprus           2004-05-01   1960-09-20
# Malta            2004-05-01   1964-12-01
# Estonia          2004-05-01   1991-09-17
# Latvia           2004-05-01   1991-09-17
# Lithuania        2004-05-01   1991-09-17
# Slovenia         2004-05-01   1992-05-22
# Czechia          2004-05-01   1993-01-19
# Slovakia         2004-05-01   1993-01-19
# Bulgaria         2007-01-01   1955-12-14
# Romania          2007-01-01   1955-12-14
# Croatia          2013-01-01   1992-05-22

# %% [markdown]
# > ### HOMEWORK Task
# 1. Sort the countries of the world according to population density.
# 2. Which countries have overweight problems (average BMI of men and women is over 25)
# 3. In which 20 countries do absolutely most people die in car accidents?

# %%
#Your code goes here...

# %% [markdown]
# ## Save Results!
# And that's slowly the end of it. But we have done a great amount of work and don't get frustrated if you forget most of it until the next time. Feel free to always come back to this notebook.
#
# Fortunately, writing an `DataFrame` to an external file in one of the typical extensions is not complicated at all. There are counterparts to the `pd.read_XXX` function set,` DataFrame.to_XXX`. They differ in different parameters, but the basic use is very simple:

# %%
planets.to_csv("planets.csv")

# %%
planets.to_excel("planets.xlsx")

# %% [markdown]
# Excel and CSV are not completely suitable formats for storing large data (alternatives are `feather` (https://github.com/wesm/feather) or `parquet` (https://en.wikipedia.org/wiki/Apache_Parquet)), for our purposes (small files, readable text format) CSV will suffice.

# %% [markdown]
# One of the possibilities is to create an HTML table (which can be supplied with various formatting, which we should leave for another time or at home, see [documentation "Styling"] (https://pandas.pydata.org/pandas-docs/stable/ user_guide/style.html)):

# %%
planets.to_html("planets.html")

# %% [markdown]
# > ### HOMEWORK Task
# 1. See what you find in the output files.
# 2. Look at the list of possible output formats and try to write planets or countries in one of them: https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#serialization-io-conversion

# %%
#Your code goes here...

# %% [markdown]
# And that&#39;s really all. 👋
